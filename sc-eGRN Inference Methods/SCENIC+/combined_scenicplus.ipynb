# %% [markdown]
# # Inferring enhancer-driven Gene Regulatory Networks (eGRNs) using SCENIC+

# %%
# Set up Environment
import dill
import scanpy as sc
import os
import warnings
warnings.filterwarnings("ignore")
import pandas
import pyranges
# Set stderr to null to avoid strange messages from ray
import sys
_stderr = sys.stderr
null = open(os.devnull,'wb')

# set working directory
work_dir = '/g/scb/zaugg/deuner/SCENIC+/'
# set tmp directory
tmp_dir = '/g/scb/zaugg/deuner/SCENIC+/tmp/combined/'
# set the figures directory
fig_dir = '/g/scb/zaugg/deuner/SCENIC+/figures/'
# set the output data directory
out_dir = '/g/scb/zaugg/deuner/SCENIC+/outputdata/'

# Load the AnnData object containing the scRNA-seq side of the analysis
adata = sc.read_h5ad(os.path.join(tmp_dir, 'combined.nomicro.adata.h5ad'))

# Load the cisTopic object containing the scATAC-seq side of the analysis.
cistopic_obj = dill.load(open(os.path.join(tmp_dir, 'scATAC/cistopic_obj.pkl'), 'rb'))

# Load the motif enrichment dictionary containing the motif enrichment results.
menr = dill.load(open(os.path.join(tmp_dir, 'motifs/menr.pkl'), 'rb'))

# %%
cistopic_obj.cell_data
# Out:
#                                Dupl_rate cisTopic_log_nr_acc  \
# TCAATTGCTCCTGAGT_timecourse     0.992421            3.625621
# TGAACCGACTATCCTG_timecourse     0.992839            3.804957
# GGATTAGTGGCTTTAA_timecourse     0.992924            4.093352
# AAGCCTAACTAATCAG_timecourse     0.992291            4.273441
# GGCGGTTACCTGGATG_timecourse     0.992954            3.723948
# ...                                  ...                 ...
# GATGAAGGAGGCCCTT_cocultured28   0.993454            3.123525
# CTGTATTGATCCTAAT_cocultured28   0.992931            3.394802
# CCTAAGCCTTGAGGTA_cocultured28   0.993037            3.474216
# TCCACAATGCGTGATT_cocultured28   0.993336            3.218273
# GTGCGAGTGCAAGCTT_cocultured28   0.992965            3.186956
#
#                                Total_nr_frag_in_regions  Log_total_nr_frag  \
# TCAATTGCTCCTGAGT_timecourse                      470578           5.885086
# TGAACCGACTATCCTG_timecourse                      781384           6.076014
# GGATTAGTGGCTTTAA_timecourse                     1642543           6.460567
# AAGCCTAACTAATCAG_timecourse                     2496161           6.590419
# GGCGGTTACCTGGATG_timecourse                      655078           6.012438
# ...                                                 ...                ...
# GATGAAGGAGGCCCTT_cocultured28                    190524           5.496168
# CTGTATTGATCCTAAT_cocultured28                    336729           5.666258
# CCTAAGCCTTGAGGTA_cocultured28                    413668           5.762289
# TCCACAATGCGTGATT_cocultured28                    220009           5.499695
# GTGCGAGTGCAAGCTT_cocultured28                    196610           5.469131
#
#                                Total_nr_frag cisTopic_nr_frag  \
# TCAATTGCTCCTGAGT_timecourse           767513             4379
# TGAACCGACTATCCTG_timecourse          1191281             6794
# GGATTAGTGGCTTTAA_timecourse          2887798            13338
# AAGCCTAACTAATCAG_timecourse          3894208            20864
# GGCGGTTACCTGGATG_timecourse          1029054             5564
# ...                                      ...              ...
# GATGAAGGAGGCCCTT_cocultured28         313450             1379
# CTGTATTGATCCTAAT_cocultured28         463722             2584
# CCTAAGCCTTGAGGTA_cocultured28         578481             3171
# TCCACAATGCGTGATT_cocultured28         316006             1693
# GTGCGAGTGCAAGCTT_cocultured28         294531             1590
#
#                                Unique_nr_frag_in_regions  Log_unique_nr_frag  \
# TCAATTGCTCCTGAGT_timecourse                         3350            3.764699
# TGAACCGACTATCCTG_timecourse                         5182            3.931000
# GGATTAGTGGCTTTAA_timecourse                        11197            4.310375
# AAGCCTAACTAATCAG_timecourse                        19777            4.477411
# GGCGGTTACCTGGATG_timecourse                         4457            3.860398
# ...                                                  ...                 ...
# GATGAAGGAGGCCCTT_cocultured28                       1164            3.312177
# CTGTATTGATCCTAAT_cocultured28                       2166            3.515609
# CCTAAGCCTTGAGGTA_cocultured28                       2706            3.605089
# TCCACAATGCGTGATT_cocultured28                       1345            3.323458
# GTGCGAGTGCAAGCTT_cocultured28                       1268            3.316390
#
#                               cisTopic_nr_acc cisTopic_log_nr_frag  ...  \
# TCAATTGCTCCTGAGT_timecourse              4223             3.641375  ...
# TGAACCGACTATCCTG_timecourse              6382             3.832126  ...
# GGATTAGTGGCTTTAA_timecourse             12398             4.125091  ...
# AAGCCTAACTAATCAG_timecourse             18769             4.319398  ...
# GGCGGTTACCTGGATG_timecourse              5296             3.745387  ...
# ...                                       ...                  ...  ...
# GATGAAGGAGGCCCTT_cocultured28            1329             3.139564  ...
# CTGTATTGATCCTAAT_cocultured28            2482             3.412293  ...
# CCTAAGCCTTGAGGTA_cocultured28            2980             3.501196  ...
# TCCACAATGCGTGATT_cocultured28            1653             3.228657  ...
# GTGCGAGTGCAAGCTT_cocultured28            1538             3.201397  ...
#
#                                wsnn_res.9  wsnn_res.10  wsnn_res.12  \
# TCAATTGCTCCTGAGT_timecourse            47           49           50
# TGAACCGACTATCCTG_timecourse            34           32           26
# GGATTAGTGGCTTTAA_timecourse            55           40            8
# AAGCCTAACTAATCAG_timecourse            50           97          105
# GGCGGTTACCTGGATG_timecourse             8           37           22
# ...                                   ...          ...          ...
# GATGAAGGAGGCCCTT_cocultured28         104          108          127
# CTGTATTGATCCTAAT_cocultured28          33           43           29
# CCTAAGCCTTGAGGTA_cocultured28          22           14           55
# TCCACAATGCGTGATT_cocultured28          15           61           62
# GTGCGAGTGCAAGCTT_cocultured28          15           61           62
#
#                                wsnn_res.14 wsnn_res.16  wsnn_res.18  \
# TCAATTGCTCCTGAGT_timecourse             47          34          147
# TGAACCGACTATCCTG_timecourse             23          14           62
# GGATTAGTGGCTTTAA_timecourse             61          50           36
# AAGCCTAACTAATCAG_timecourse            113         114          125
# GGCGGTTACCTGGATG_timecourse             70          48          143
# ...                                    ...         ...          ...
# GATGAAGGAGGCCCTT_cocultured28          132         148          157
# CTGTATTGATCCTAAT_cocultured28           21          45           73
# CCTAAGCCTTGAGGTA_cocultured28           49          94           80
# TCCACAATGCGTGATT_cocultured28           57         134          129
# GTGCGAGTGCAAGCTT_cocultured28           57         142          152
#
#                                wsnn_res.20  celltype_wnn           barcode  \
# TCAATTGCTCCTGAGT_timecourse            151       hiPSC-2  TCAATTGCTCCTGAGT
# TGAACCGACTATCCTG_timecourse             50   diff-neuron  TGAACCGACTATCCTG
# GGATTAGTGGCTTTAA_timecourse             21       hiPSC-1  GGATTAGTGGCTTTAA
# AAGCCTAACTAATCAG_timecourse            115       hiPSC-2  AAGCCTAACTAATCAG
# GGCGGTTACCTGGATG_timecourse            156      diff-NPC  GGCGGTTACCTGGATG
# ...                                    ...           ...               ...
# GATGAAGGAGGCCCTT_cocultured28          164      neuron-3  GATGAAGGAGGCCCTT
# CTGTATTGATCCTAAT_cocultured28           48      neuron-3  CTGTATTGATCCTAAT
# CCTAAGCCTTGAGGTA_cocultured28           90      neuron-2  CCTAAGCCTTGAGGTA
# TCCACAATGCGTGATT_cocultured28          136      neuron-3  TCCACAATGCGTGATT
# GTGCGAGTGCAAGCTT_cocultured28          123      neuron-3  GTGCGAGTGCAAGCTT
#
#                                   sample_id
# TCAATTGCTCCTGAGT_timecourse      timecourse
# TGAACCGACTATCCTG_timecourse      timecourse
# GGATTAGTGGCTTTAA_timecourse      timecourse
# AAGCCTAACTAATCAG_timecourse      timecourse
# GGCGGTTACCTGGATG_timecourse      timecourse
# ...                                     ...
# GATGAAGGAGGCCCTT_cocultured28  cocultured28
# CTGTATTGATCCTAAT_cocultured28  cocultured28
# CCTAAGCCTTGAGGTA_cocultured28  cocultured28
# TCCACAATGCGTGATT_cocultured28  cocultured28
# GTGCGAGTGCAAGCTT_cocultured28  cocultured28
#
# [19827 rows x 69 columns]

# %%
# adapt barcodes of cistopic object
new_bcs = []
old_bcs = cistopic_obj.cell_names
for i in range(len(old_bcs)):
    split_bc = str.split(old_bcs[i], "_")
    new_bc = split_bc[1] + "_" + split_bc[0]
    new_bcs.append(new_bc)
    cistopic_obj.selected_model.cell_topic.columns.values[i] = new_bc

cistopic_obj.cell_names = new_bcs

# %%
cistopic_obj.cell_data.index = new_bcs

# %%
cistopic_obj.selected_model.cell_topic
# Out:
#          timecourse_TCAATTGCTCCTGAGT  timecourse_TGAACCGACTATCCTG  \
# Topic1                      0.012872                     0.448228
# Topic2                      0.014978                     0.040112
# Topic3                      0.008893                     0.008240
# Topic4                      0.628130                     0.006063
# Topic5                      0.078399                     0.091573
# Topic6                      0.065996                     0.024720
# Topic7                      0.051252                     0.004509
# Topic8                      0.121226                     0.168532
# Topic9                      0.010765                     0.165578
# Topic10                     0.007489                     0.042444
#
#          timecourse_GGATTAGTGGCTTTAA  timecourse_AAGCCTAACTAATCAG  \
# Topic1                      0.022895                     0.016632
# Topic2                      0.035749                     0.016526
# Topic3                      0.024100                     0.029332
# Topic4                      0.539444                     0.622403
# Topic5                      0.194489                     0.182209
# Topic6                      0.112870                     0.075774
# Topic7                      0.040167                     0.036612
# Topic8                      0.009399                     0.006908
# Topic9                      0.010925                     0.009299
# Topic10                     0.009961                     0.004304
#
#          timecourse_GGCGGTTACCTGGATG  timecourse_CGTTAAGGAGTCAATA  \
# Topic1                      0.392630                     0.026084
# Topic2                      0.285073                     0.021246
# Topic3                      0.025065                     0.015081
# Topic4                      0.034979                     0.015650
# Topic5                      0.139731                     0.139144
# Topic6                      0.041152                     0.062790
# Topic7                      0.008792                     0.008821
# Topic8                      0.066218                     0.349331
# Topic9                      0.003928                     0.012330
# Topic10                     0.002432                     0.349521
#
#          timecourse_GATAGCCGACCTTTGG  timecourse_CACCACACTATCCTCC  \
# Topic1                      0.136395                     0.428571
# Topic2                      0.023561                     0.248934
# Topic3                      0.011223                     0.025586
# Topic4                      0.011138                     0.031983
# Topic5                      0.110093                     0.086887
# Topic6                      0.036155                     0.049574
# Topic7                      0.009853                     0.015458
# Topic8                      0.258482                     0.098081
# Topic9                      0.037611                     0.007996
# Topic10                     0.365490                     0.006930
#
#          timecourse_GATTTGGACCCACATT  timecourse_CCAACCTGACCGTTGT  ...  \
# Topic1                      0.427873                     0.222501  ...
# Topic2                      0.359294                     0.453219  ...
# Topic3                      0.014977                     0.009376  ...
# Topic4                      0.008671                     0.056157  ...
# Topic5                      0.091597                     0.164315  ...
# Topic6                      0.041621                     0.021748  ...
# Topic7                      0.012770                     0.018848  ...
# Topic8                      0.030427                     0.043882  ...
# Topic9                      0.004572                     0.004833  ...
# Topic10                     0.008198                     0.005123  ...
#
#          cocultured28_AGCAATACTACATAAG  cocultured28_AGGAAGCACAATTGGC  \
# Topic1                        0.009130                       0.034632
# Topic2                        0.021144                       0.010462
# Topic3                        0.013455                       0.008658
# Topic4                        0.024027                       0.009019
# Topic5                        0.060067                       0.040043
# Topic6                        0.037963                       0.008658
# Topic7                        0.018260                       0.027417
# Topic8                        0.676117                       0.691919
# Topic9                        0.095147                       0.123737
# Topic10                       0.044690                       0.045455
#
#          cocultured28_TGAATTGACTTCATCG  cocultured28_CCACTATACCTAGTCT  \
# Topic1                        0.055914                       0.020237
# Topic2                        0.012289                       0.011455
# Topic3                        0.019969                       0.012600
# Topic4                        0.017512                       0.019855
# Topic5                        0.022427                       0.112257
# Topic6                        0.003687                       0.019855
# Topic7                        0.028571                       0.009164
# Topic8                        0.686022                       0.639939
# Topic9                        0.132719                       0.086292
# Topic10                       0.020891                       0.068347
#
#          cocultured28_ATGGCTAACGCTTGCT  cocultured28_GATGAAGGAGGCCCTT  \
# Topic1                        0.050934                       0.094996
# Topic2                        0.026599                       0.019579
# Topic3                        0.016412                       0.035533
# Topic4                        0.019808                       0.042059
# Topic5                        0.020374                       0.108049
# Topic6                        0.021505                       0.060914
# Topic7                        0.022071                       0.020305
# Topic8                        0.441426                       0.459028
# Topic9                        0.015846                       0.038434
# Topic10                       0.365025                       0.121102
#
#          cocultured28_CTGTATTGATCCTAAT  cocultured28_CCTAAGCCTTGAGGTA  \
# Topic1                        0.041469                       0.011221
# Topic2                        0.019747                       0.012871
# Topic3                        0.009084                       0.009241
# Topic4                        0.026856                       0.017822
# Topic5                        0.032385                       0.024092
# Topic6                        0.025276                       0.013531
# Topic7                        0.015403                       0.010891
# Topic8                        0.425750                       0.728053
# Topic9                        0.006319                       0.077228
# Topic10                       0.397709                       0.095050
#
#          cocultured28_TCCACAATGCGTGATT  cocultured28_GTGCGAGTGCAAGCTT
# Topic1                        0.039930                       0.019521
# Topic2                        0.039930                       0.034635
# Topic3                        0.012331                       0.015743
# Topic4                        0.018203                       0.018262
# Topic5                        0.056371                       0.032746
# Topic6                        0.032296                       0.005668
# Topic7                        0.028773                       0.030227
# Topic8                        0.410452                       0.518892
# Topic9                        0.019378                       0.013224
# Topic10                       0.342337                       0.311083
#
# [10 rows x 19827 columns]

# %%
adata.obs
adata.obs_names.copy(deep=True)
# Out:
# Index(['timecourse_AAACAGCCAGCCAGTT', 'timecourse_AAACAGCCAGGCGAGT',
#        'timecourse_AAACAGCCAGTAAAGC', 'timecourse_AAACAGCCATAAGTCT',
#        'timecourse_AAACAGCCATAGGCGA', 'timecourse_AAACAGCCATCACAGC',
#        'timecourse_AAACATGCAACTAGCC', 'timecourse_AAACATGCAAGACTCC',
#        'timecourse_AAACATGCAGCACCAT', 'timecourse_AAACATGCAGCATTAT',
#        ...
#        'cocultured28_TTTGTCTAGGCGCTTA', 'cocultured28_TTTGTCTAGTGCACGC',
#        'cocultured28_TTTGTGAAGCTTAGTA', 'cocultured28_TTTGTGAAGGGTGAAC',
#        'cocultured28_TTTGTGAAGGGTGGAT', 'cocultured28_TTTGTGAAGTCTATGA',
#        'cocultured28_TTTGTGGCAGCAAGTG', 'cocultured28_TTTGTGTTCTCGCCTG',
#        'cocultured28_TTTGTGTTCTTAGCCC', 'cocultured28_TTTGTGTTCTTGCAGG'],
#       dtype='object', length=22367)

# %%
len(set(adata.obs_names)) == len(adata.obs_names)
# Out:
# True

# %%
# check if there are common barcodes
list(set(adata.obs_names.copy(deep=True)) & set(list(cistopic_obj.cell_names.copy())))
# Out:
# []

# %%
len(set(list(cistopic_obj.cell_names.copy()))) > 0
# Out:
# True

# %%
# maybe select the atac barcodes as defaults for adata
list(set(adata.obs["barcode"]) & set(list(cistopic_obj.cell_names.copy())))

l_bcs = []

for i in range(len(adata.obs_names)):
     l_bc = adata.obs["orig.ident"][i] + "_" + adata.obs["barcode"][i]
     l_bcs.append(l_bc)
     
adata.obs["long_barcode"] = l_bcs
adata.obs_names = list(adata.obs["long_barcode"])

# %%
adata.obs
# Out:
#                                  orig.ident  nCount_RNA  nFeature_RNA  \
# timecourse_AAACCGTACCCGCTGT      timecourse      5020.0          2676
# timecourse_GTAGGTTACCCGCTGT      timecourse      4719.0          2179
# timecourse_CTAGTAAACCCGCTGT      timecourse      3832.0          2004
# timecourse_TGGCATGACCCGCTGT      timecourse      7329.0          3535
# timecourse_TTTGTGCACCCGCTGT      timecourse      4511.0          2253
# ...                                     ...         ...           ...
# cocultured28_AGCAATTGACACCTAC  cocultured28     11717.0          3893
# cocultured28_TGATTAGACACCAAAC  cocultured28      6845.0          2998
# cocultured28_GTTAAAGCTTGAGAAC  cocultured28      9557.0          3435
# cocultured28_ACTAAGACTTGAGAAC  cocultured28      1732.0          1112
# cocultured28_AAGGAAGCTTGAGAAC  cocultured28      8505.0          3170
#
#                                percent.mt  percent.ribo  nCount_SCT  \
# timecourse_AAACCGTACCCGCTGT      6.155378      3.705179      6037.0
# timecourse_GTAGGTTACCCGCTGT      0.190718      0.466200      6032.0
# timecourse_CTAGTAAACCCGCTGT      0.287056      0.730689      5979.0
# timecourse_TGGCATGACCCGCTGT      1.159776      1.132487      7247.0
# timecourse_TTTGTGCACCCGCTGT      7.337619      1.906451      6061.0
# ...                                   ...           ...         ...
# cocultured28_AGCAATTGACACCTAC    0.162158      0.187761      7918.0
# cocultured28_TGATTAGACACCAAAC    0.613587      0.555150      6845.0
# cocultured28_GTTAAAGCTTGAGAAC    0.292979      0.282515      7697.0
# cocultured28_ACTAAGACTTGAGAAC    2.078522      0.577367      5364.0
# cocultured28_AAGGAAGCTTGAGAAC    0.282187      0.435038      7565.0
#
#                                nFeature_SCT SCT_snn_res.0.5 seurat_clusters  \
# timecourse_AAACCGTACCCGCTGT            2676               7              25
# timecourse_GTAGGTTACCCGCTGT            2178              14             117
# timecourse_CTAGTAAACCCGCTGT            2008              12              50
# timecourse_TGGCATGACCCGCTGT            3535               8             151
# timecourse_TTTGTGCACCCGCTGT            2253               7              51
# ...                                     ...             ...             ...
# cocultured28_AGCAATTGACACCTAC          3746               5              72
# cocultured28_TGATTAGACACCAAAC          2998              14              85
# cocultured28_GTTAAAGCTTGAGAAC          3433               6              39
# cocultured28_ACTAAGACTTGAGAAC          1614               6             123
# cocultured28_AAGGAAGCTTGAGAAC          3170               6              48
#
#                                pANN_0.25_0.005_794  ... wsnn_res.9  \
# timecourse_AAACCGTACCCGCTGT               0.084507  ...         48
# timecourse_GTAGGTTACCCGCTGT               0.239437  ...         96
# timecourse_CTAGTAAACCCGCTGT               0.183099  ...         34
# timecourse_TGGCATGACCCGCTGT               0.154930  ...         47
# timecourse_TTTGTGCACCCGCTGT               0.140845  ...         11
# ...                                            ...  ...        ...
# cocultured28_AGCAATTGACACCTAC                  NaN  ...         22
# cocultured28_TGATTAGACACCAAAC                  NaN  ...         88
# cocultured28_GTTAAAGCTTGAGAAC                  NaN  ...         15
# cocultured28_ACTAAGACTTGAGAAC                  NaN  ...         33
# cocultured28_AAGGAAGCTTGAGAAC                  NaN  ...         33
#
#                               wsnn_res.10 wsnn_res.12  wsnn_res.14  \
# timecourse_AAACCGTACCCGCTGT            44          31           27
# timecourse_GTAGGTTACCCGCTGT            96         109          114
# timecourse_CTAGTAAACCCGCTGT            32          26           23
# timecourse_TGGCATGACCCGCTGT            49          50           47
# timecourse_TTTGTGCACCCGCTGT            12          41           36
# ...                                   ...         ...          ...
# cocultured28_AGCAATTGACACCTAC          14          55           49
# cocultured28_TGATTAGACACCAAAC          89         100          103
# cocultured28_GTTAAAGCTTGAGAAC          70          79           78
# cocultured28_ACTAAGACTTGAGAAC          61          29           21
# cocultured28_AAGGAAGCTTGAGAAC          43          29           21
#
#                                wsnn_res.16  wsnn_res.18  wsnn_res.20  \
# timecourse_AAACCGTACCCGCTGT             51           35           25
# timecourse_GTAGGTTACCCGCTGT            120          115          117
# timecourse_CTAGTAAACCCGCTGT             14           62           50
# timecourse_TGGCATGACCCGCTGT             34          147          151
# timecourse_TTTGTGCACCCGCTGT             70           52           51
# ...                                    ...          ...          ...
# cocultured28_AGCAATTGACACCTAC          107          105           72
# cocultured28_TGATTAGACACCAAAC          105           93           85
# cocultured28_GTTAAAGCTTGAGAAC           73           50           39
# cocultured28_ACTAAGACTTGAGAAC           45           73          123
# cocultured28_AAGGAAGCTTGAGAAC           45          134           48
#
#                                celltype_wnn           barcode  \
# timecourse_AAACCGTACCCGCTGT        diff-NPC  AAACCGTACCCGCTGT
# timecourse_GTAGGTTACCCGCTGT        neuron-1  GTAGGTTACCCGCTGT
# timecourse_CTAGTAAACCCGCTGT     diff-neuron  CTAGTAAACCCGCTGT
# timecourse_TGGCATGACCCGCTGT         hiPSC-2  TGGCATGACCCGCTGT
# timecourse_TTTGTGCACCCGCTGT        diff-NPC  TTTGTGCACCCGCTGT
# ...                                     ...               ...
# cocultured28_AGCAATTGACACCTAC      neuron-2  AGCAATTGACACCTAC
# cocultured28_TGATTAGACACCAAAC      neuron-4  TGATTAGACACCAAAC
# cocultured28_GTTAAAGCTTGAGAAC      neuron-3  GTTAAAGCTTGAGAAC
# cocultured28_ACTAAGACTTGAGAAC      neuron-3  ACTAAGACTTGAGAAC
# cocultured28_AAGGAAGCTTGAGAAC      neuron-3  AAGGAAGCTTGAGAAC
#
#                                                 long_barcode
# timecourse_AAACCGTACCCGCTGT      timecourse_AAACCGTACCCGCTGT
# timecourse_GTAGGTTACCCGCTGT      timecourse_GTAGGTTACCCGCTGT
# timecourse_CTAGTAAACCCGCTGT      timecourse_CTAGTAAACCCGCTGT
# timecourse_TGGCATGACCCGCTGT      timecourse_TGGCATGACCCGCTGT
# timecourse_TTTGTGCACCCGCTGT      timecourse_TTTGTGCACCCGCTGT
# ...                                                      ...
# cocultured28_AGCAATTGACACCTAC  cocultured28_AGCAATTGACACCTAC
# cocultured28_TGATTAGACACCAAAC  cocultured28_TGATTAGACACCAAAC
# cocultured28_GTTAAAGCTTGAGAAC  cocultured28_GTTAAAGCTTGAGAAC
# cocultured28_ACTAAGACTTGAGAAC  cocultured28_ACTAAGACTTGAGAAC
# cocultured28_AAGGAAGCTTGAGAAC  cocultured28_AAGGAAGCTTGAGAAC
#
# [22367 rows x 55 columns]

# %%
len(set(adata.obs_names)) == len(adata.obs_names)
# Out:
# True

# %%
# do the same for the cistopic object
cistopic_obj.cell_data["long_barcode"] = cistopic_obj.cell_names

# %%
# check if there are common barcodes
len(list(set(adata.obs_names.copy(deep=True)) & set(list(cistopic_obj.cell_names.copy())))) #128
#len(list(set(adata.obs_names.copy(deep=True)))) #757
#len(set(list(cistopic_obj.cell_names.copy())))  #128
# Out:
# 19622

# %%
cistopic_obj.selected_model.cell_topic.columns.values
# Out:
# array(['timecourse_TCAATTGCTCCTGAGT', 'timecourse_TGAACCGACTATCCTG',
#        'timecourse_GGATTAGTGGCTTTAA', ...,
#        'cocultured28_CCTAAGCCTTGAGGTA', 'cocultured28_TCCACAATGCGTGATT',
#        'cocultured28_GTGCGAGTGCAAGCTT'], dtype=object)

# %%
#from pycisTopic.cistopic_class import *
#from pycisTopic.diff_features import *
#common_cells = list(set(adata.obs_names.copy(deep=True)) & set(list(cistopic_obj.cell_names.copy())))
#impute_accessibility(cistopic_obj, selected_cells=common_cells)

# %%
print(len(adata.obs_names.copy(deep=True)) == len(set(adata.obs_names.copy(deep=True))))
print(len(adata.obs_names.copy(deep=True).drop_duplicates(keep='first')))
print(len(set(adata.obs_names.copy(deep=True))))
print(len(list(cistopic_obj.cell_names.copy())) == len(set(list(cistopic_obj.cell_names.copy()))))
print(len(list(cistopic_obj.cell_names.copy())))
print(len(set(list(cistopic_obj.cell_names.copy()))))
# Out:
# True
# 22367
# 22367
# True
# 19827
# 19827

# %% [markdown]
# ## Create SCENIC+ object

# %%
# Create the Scenic+ object
from scenicplus.scenicplus_class import create_SCENICPLUS_object
import numpy as np
scplus_obj = create_SCENICPLUS_object(
    GEX_anndata = adata,
    cisTopic_obj = cistopic_obj,
    menr = menr,
    gene_metadata = adata.var.copy(deep=True),
    bc_transform_func = None, #lambda x: f'{x}_timecourse' #None, #function to convert scATAC-seq barcodes to scRNA-seq ones
)
scplus_obj.X_EXP = np.array(scplus_obj.X_EXP.todense())
scplus_obj
# Out:
# 2023-05-28 10:48:23,288 cisTopic     INFO     Imputing drop-outs
# 2023-05-28 10:48:56,811 cisTopic     INFO     Scaling
# 2023-05-28 10:49:36,280 cisTopic     INFO     Keep non zero rows
# 2023-05-28 10:50:13,752 cisTopic     INFO     Imputed accessibility sparsity: 0.6699118462550895
# 2023-05-28 10:50:13,754 cisTopic     INFO     Create CistopicImputedFeatures object
# 2023-05-28 10:50:13,755 cisTopic     INFO     Done!
# SCENIC+ object with n_cells x n_genes = 19622 x 30768 and n_cells x n_regions = 19622 x 538878
# 	metadata_regions:'Chromosome', 'Start', 'End', 'Width', 'cisTopic_nr_frag', 'cisTopic_log_nr_frag', 'cisTopic_nr_acc', 'cisTopic_log_nr_acc'
# 	metadata_genes:'features'
# 	metadata_cell:'GEX_orig.ident', 'GEX_nCount_RNA', 'GEX_nFeature_RNA', 'GEX_percent.mt', 'GEX_percent.ribo', 'GEX_nCount_SCT', 'GEX_nFeature_SCT', 'GEX_SCT_snn_res.0.5', 'GEX_seurat_clusters', 'GEX_pANN_0.25_0.005_794', 'GEX_DF.classifications_0.25_0.005_794', 'GEX_doubletClass', 'GEX_bc', 'GEX_nCount_ATAC', 'GEX_nFeature_ATAC', 'GEX_SCT.weight', 'GEX_ATAC.weight', 'GEX_pANN_0.25_0.005_398', 'GEX_DF.classifications_0.25_0.005_398', 'GEX_pANN_0.25_0.005_1306', 'GEX_DF.classifications_0.25_0.005_1306', 'GEX_pANN_0.25_0.005_395', 'GEX_DF.classifications_0.25_0.005_395', 'GEX_ident', 'GEX_scDblFinder.sample', 'GEX_scDblFinder.class', 'GEX_scDblFinder.score', 'GEX_scDblFinder.weighted', 'GEX_scDblFinder.cxds_score', 'GEX_res.0.5', 'GEX_celltype', 'GEX_pseudotime', 'GEX_wsnn_res.0.8', 'GEX_wsnn_res.0.1', 'GEX_wsnn_res.0.25', 'GEX_wsnn_res.0.5', 'GEX_wsnn_res.0.75', 'GEX_wsnn_res.1', 'GEX_wsnn_res.2', 'GEX_wsnn_res.3', 'GEX_wsnn_res.4', 'GEX_wsnn_res.5', 'GEX_wsnn_res.6', 'GEX_wsnn_res.7', 'GEX_wsnn_res.8', 'GEX_wsnn_res.9', 'GEX_wsnn_res.10', 'GEX_wsnn_res.12', 'GEX_wsnn_res.14', 'GEX_wsnn_res.16', 'GEX_wsnn_res.18', 'GEX_wsnn_res.20', 'GEX_celltype_wnn', 'GEX_barcode', 'GEX_long_barcode', 'ACC_Dupl_rate', 'ACC_cisTopic_log_nr_acc', 'ACC_Total_nr_frag_in_regions', 'ACC_Log_total_nr_frag', 'ACC_Total_nr_frag', 'ACC_cisTopic_nr_frag', 'ACC_Unique_nr_frag_in_regions', 'ACC_Log_unique_nr_frag', 'ACC_cisTopic_nr_acc', 'ACC_cisTopic_log_nr_frag', 'ACC_Unique_nr_frag', 'ACC_Dupl_nr_frag', 'ACC_TSS_enrichment', 'ACC_FRIP', 'ACC_orig.ident', 'ACC_nCount_RNA', 'ACC_nFeature_RNA', 'ACC_percent.mt', 'ACC_percent.ribo', 'ACC_nCount_SCT', 'ACC_nFeature_SCT', 'ACC_SCT_snn_res.0.5', 'ACC_seurat_clusters', 'ACC_pANN_0.25_0.005_794', 'ACC_DF.classifications_0.25_0.005_794', 'ACC_doubletClass', 'ACC_bc', 'ACC_nCount_ATAC', 'ACC_nFeature_ATAC', 'ACC_SCT.weight', 'ACC_ATAC.weight', 'ACC_pANN_0.25_0.005_398', 'ACC_DF.classifications_0.25_0.005_398', 'ACC_pANN_0.25_0.005_1306', 'ACC_DF.classifications_0.25_0.005_1306', 'ACC_pANN_0.25_0.005_395', 'ACC_DF.classifications_0.25_0.005_395', 'ACC_ident', 'ACC_scDblFinder.sample', 'ACC_scDblFinder.class', 'ACC_scDblFinder.score', 'ACC_scDblFinder.weighted', 'ACC_scDblFinder.cxds_score', 'ACC_res.0.5', 'ACC_celltype', 'ACC_pseudotime', 'ACC_wsnn_res.0.8', 'ACC_wsnn_res.0.1', 'ACC_wsnn_res.0.25', 'ACC_wsnn_res.0.5', 'ACC_wsnn_res.0.75', 'ACC_wsnn_res.1', 'ACC_wsnn_res.2', 'ACC_wsnn_res.3', 'ACC_wsnn_res.4', 'ACC_wsnn_res.5', 'ACC_wsnn_res.6', 'ACC_wsnn_res.7', 'ACC_wsnn_res.8', 'ACC_wsnn_res.9', 'ACC_wsnn_res.10', 'ACC_wsnn_res.12', 'ACC_wsnn_res.14', 'ACC_wsnn_res.16', 'ACC_wsnn_res.18', 'ACC_wsnn_res.20', 'ACC_celltype_wnn', 'ACC_barcode', 'ACC_sample_id', 'ACC_long_barcode'
# 	menr:'CTX_topics_otsu_All', 'CTX_topics_otsu_No_promoters', 'DEM_topics_otsu_All', 'DEM_topics_otsu_No_promoters', 'CTX_topics_top_3_All', 'CTX_topics_top_3_No_promoters', 'DEM_topics_top_3_All', 'DEM_topics_top_3_No_promoters', 'CTX_DARs_All', 'CTX_DARs_No_promoters', 'DEM_DARs_All', 'DEM_DARs_No_promoters'
# 	dr_cell:'GEX_X_umap', 'GEX_X_umap.atac', 'GEX_X_wnn.umap'

# %%
#scplus_obj.add_gene_data(adata.var.copy(deep=True))

# %%
scplus_obj.gene_names
# Out:
# Index(['MIR1302-2HG', 'AL627309.1', 'AL627309.5', 'AL627309.4', 'AP006222.2',
#        'AC114498.1', 'AL669831.2', 'LINC01409', 'FAM87B', 'LINC01128',
#        ...
#        'HSFX3', 'HSFX4', 'MAGEA4', 'U82671.1', 'AVPR2', 'HCFC1-AS1',
#        'AC009494.2', 'AC136616.3', 'AC023491.2', 'AC007325.1'],
#       dtype='object', length=30768)

# %%
adata.var
adata.var.copy(deep=True)
adata.var.index
# Out:
# Index(['MIR1302-2HG', 'AL627309.1', 'AL627309.5', 'AL627309.4', 'AP006222.2',
#        'AC114498.1', 'AL669831.2', 'LINC01409', 'FAM87B', 'LINC01128',
#        ...
#        'HSFX3', 'HSFX4', 'MAGEA4', 'U82671.1', 'AVPR2', 'HCFC1-AS1',
#        'AC009494.2', 'AC136616.3', 'AC023491.2', 'AC007325.1'],
#       dtype='object', length=30768)

# %%
adata.obs
# Out:
#                                  orig.ident  nCount_RNA  nFeature_RNA  \
# timecourse_AAACCGTACCCGCTGT      timecourse      5020.0          2676
# timecourse_GTAGGTTACCCGCTGT      timecourse      4719.0          2179
# timecourse_CTAGTAAACCCGCTGT      timecourse      3832.0          2004
# timecourse_TGGCATGACCCGCTGT      timecourse      7329.0          3535
# timecourse_TTTGTGCACCCGCTGT      timecourse      4511.0          2253
# ...                                     ...         ...           ...
# cocultured28_AGCAATTGACACCTAC  cocultured28     11717.0          3893
# cocultured28_TGATTAGACACCAAAC  cocultured28      6845.0          2998
# cocultured28_GTTAAAGCTTGAGAAC  cocultured28      9557.0          3435
# cocultured28_ACTAAGACTTGAGAAC  cocultured28      1732.0          1112
# cocultured28_AAGGAAGCTTGAGAAC  cocultured28      8505.0          3170
#
#                                percent.mt  percent.ribo  nCount_SCT  \
# timecourse_AAACCGTACCCGCTGT      6.155378      3.705179      6037.0
# timecourse_GTAGGTTACCCGCTGT      0.190718      0.466200      6032.0
# timecourse_CTAGTAAACCCGCTGT      0.287056      0.730689      5979.0
# timecourse_TGGCATGACCCGCTGT      1.159776      1.132487      7247.0
# timecourse_TTTGTGCACCCGCTGT      7.337619      1.906451      6061.0
# ...                                   ...           ...         ...
# cocultured28_AGCAATTGACACCTAC    0.162158      0.187761      7918.0
# cocultured28_TGATTAGACACCAAAC    0.613587      0.555150      6845.0
# cocultured28_GTTAAAGCTTGAGAAC    0.292979      0.282515      7697.0
# cocultured28_ACTAAGACTTGAGAAC    2.078522      0.577367      5364.0
# cocultured28_AAGGAAGCTTGAGAAC    0.282187      0.435038      7565.0
#
#                                nFeature_SCT SCT_snn_res.0.5 seurat_clusters  \
# timecourse_AAACCGTACCCGCTGT            2676               7              25
# timecourse_GTAGGTTACCCGCTGT            2178              14             117
# timecourse_CTAGTAAACCCGCTGT            2008              12              50
# timecourse_TGGCATGACCCGCTGT            3535               8             151
# timecourse_TTTGTGCACCCGCTGT            2253               7              51
# ...                                     ...             ...             ...
# cocultured28_AGCAATTGACACCTAC          3746               5              72
# cocultured28_TGATTAGACACCAAAC          2998              14              85
# cocultured28_GTTAAAGCTTGAGAAC          3433               6              39
# cocultured28_ACTAAGACTTGAGAAC          1614               6             123
# cocultured28_AAGGAAGCTTGAGAAC          3170               6              48
#
#                                pANN_0.25_0.005_794  ... wsnn_res.9  \
# timecourse_AAACCGTACCCGCTGT               0.084507  ...         48
# timecourse_GTAGGTTACCCGCTGT               0.239437  ...         96
# timecourse_CTAGTAAACCCGCTGT               0.183099  ...         34
# timecourse_TGGCATGACCCGCTGT               0.154930  ...         47
# timecourse_TTTGTGCACCCGCTGT               0.140845  ...         11
# ...                                            ...  ...        ...
# cocultured28_AGCAATTGACACCTAC                  NaN  ...         22
# cocultured28_TGATTAGACACCAAAC                  NaN  ...         88
# cocultured28_GTTAAAGCTTGAGAAC                  NaN  ...         15
# cocultured28_ACTAAGACTTGAGAAC                  NaN  ...         33
# cocultured28_AAGGAAGCTTGAGAAC                  NaN  ...         33
#
#                               wsnn_res.10 wsnn_res.12  wsnn_res.14  \
# timecourse_AAACCGTACCCGCTGT            44          31           27
# timecourse_GTAGGTTACCCGCTGT            96         109          114
# timecourse_CTAGTAAACCCGCTGT            32          26           23
# timecourse_TGGCATGACCCGCTGT            49          50           47
# timecourse_TTTGTGCACCCGCTGT            12          41           36
# ...                                   ...         ...          ...
# cocultured28_AGCAATTGACACCTAC          14          55           49
# cocultured28_TGATTAGACACCAAAC          89         100          103
# cocultured28_GTTAAAGCTTGAGAAC          70          79           78
# cocultured28_ACTAAGACTTGAGAAC          61          29           21
# cocultured28_AAGGAAGCTTGAGAAC          43          29           21
#
#                                wsnn_res.16  wsnn_res.18  wsnn_res.20  \
# timecourse_AAACCGTACCCGCTGT             51           35           25
# timecourse_GTAGGTTACCCGCTGT            120          115          117
# timecourse_CTAGTAAACCCGCTGT             14           62           50
# timecourse_TGGCATGACCCGCTGT             34          147          151
# timecourse_TTTGTGCACCCGCTGT             70           52           51
# ...                                    ...          ...          ...
# cocultured28_AGCAATTGACACCTAC          107          105           72
# cocultured28_TGATTAGACACCAAAC          105           93           85
# cocultured28_GTTAAAGCTTGAGAAC           73           50           39
# cocultured28_ACTAAGACTTGAGAAC           45           73          123
# cocultured28_AAGGAAGCTTGAGAAC           45          134           48
#
#                                celltype_wnn           barcode  \
# timecourse_AAACCGTACCCGCTGT        diff-NPC  AAACCGTACCCGCTGT
# timecourse_GTAGGTTACCCGCTGT        neuron-1  GTAGGTTACCCGCTGT
# timecourse_CTAGTAAACCCGCTGT     diff-neuron  CTAGTAAACCCGCTGT
# timecourse_TGGCATGACCCGCTGT         hiPSC-2  TGGCATGACCCGCTGT
# timecourse_TTTGTGCACCCGCTGT        diff-NPC  TTTGTGCACCCGCTGT
# ...                                     ...               ...
# cocultured28_AGCAATTGACACCTAC      neuron-2  AGCAATTGACACCTAC
# cocultured28_TGATTAGACACCAAAC      neuron-4  TGATTAGACACCAAAC
# cocultured28_GTTAAAGCTTGAGAAC      neuron-3  GTTAAAGCTTGAGAAC
# cocultured28_ACTAAGACTTGAGAAC      neuron-3  ACTAAGACTTGAGAAC
# cocultured28_AAGGAAGCTTGAGAAC      neuron-3  AAGGAAGCTTGAGAAC
#
#                                                 long_barcode
# timecourse_AAACCGTACCCGCTGT      timecourse_AAACCGTACCCGCTGT
# timecourse_GTAGGTTACCCGCTGT      timecourse_GTAGGTTACCCGCTGT
# timecourse_CTAGTAAACCCGCTGT      timecourse_CTAGTAAACCCGCTGT
# timecourse_TGGCATGACCCGCTGT      timecourse_TGGCATGACCCGCTGT
# timecourse_TTTGTGCACCCGCTGT      timecourse_TTTGTGCACCCGCTGT
# ...                                                      ...
# cocultured28_AGCAATTGACACCTAC  cocultured28_AGCAATTGACACCTAC
# cocultured28_TGATTAGACACCAAAC  cocultured28_TGATTAGACACCAAAC
# cocultured28_GTTAAAGCTTGAGAAC  cocultured28_GTTAAAGCTTGAGAAC
# cocultured28_ACTAAGACTTGAGAAC  cocultured28_ACTAAGACTTGAGAAC
# cocultured28_AAGGAAGCTTGAGAAC  cocultured28_AAGGAAGCTTGAGAAC
#
# [22367 rows x 55 columns]

# %%
cistopic_obj.cell_data
# Out:
#                                Dupl_rate cisTopic_log_nr_acc  \
# timecourse_TCAATTGCTCCTGAGT     0.992421            3.625621
# timecourse_TGAACCGACTATCCTG     0.992839            3.804957
# timecourse_GGATTAGTGGCTTTAA     0.992924            4.093352
# timecourse_AAGCCTAACTAATCAG     0.992291            4.273441
# timecourse_GGCGGTTACCTGGATG     0.992954            3.723948
# ...                                  ...                 ...
# cocultured28_GATGAAGGAGGCCCTT   0.993454            3.123525
# cocultured28_CTGTATTGATCCTAAT   0.992931            3.394802
# cocultured28_CCTAAGCCTTGAGGTA   0.993037            3.474216
# cocultured28_TCCACAATGCGTGATT   0.993336            3.218273
# cocultured28_GTGCGAGTGCAAGCTT   0.992965            3.186956
#
#                                Total_nr_frag_in_regions  Log_total_nr_frag  \
# timecourse_TCAATTGCTCCTGAGT                      470578           5.885086
# timecourse_TGAACCGACTATCCTG                      781384           6.076014
# timecourse_GGATTAGTGGCTTTAA                     1642543           6.460567
# timecourse_AAGCCTAACTAATCAG                     2496161           6.590419
# timecourse_GGCGGTTACCTGGATG                      655078           6.012438
# ...                                                 ...                ...
# cocultured28_GATGAAGGAGGCCCTT                    190524           5.496168
# cocultured28_CTGTATTGATCCTAAT                    336729           5.666258
# cocultured28_CCTAAGCCTTGAGGTA                    413668           5.762289
# cocultured28_TCCACAATGCGTGATT                    220009           5.499695
# cocultured28_GTGCGAGTGCAAGCTT                    196610           5.469131
#
#                                Total_nr_frag cisTopic_nr_frag  \
# timecourse_TCAATTGCTCCTGAGT           767513             4379
# timecourse_TGAACCGACTATCCTG          1191281             6794
# timecourse_GGATTAGTGGCTTTAA          2887798            13338
# timecourse_AAGCCTAACTAATCAG          3894208            20864
# timecourse_GGCGGTTACCTGGATG          1029054             5564
# ...                                      ...              ...
# cocultured28_GATGAAGGAGGCCCTT         313450             1379
# cocultured28_CTGTATTGATCCTAAT         463722             2584
# cocultured28_CCTAAGCCTTGAGGTA         578481             3171
# cocultured28_TCCACAATGCGTGATT         316006             1693
# cocultured28_GTGCGAGTGCAAGCTT         294531             1590
#
#                                Unique_nr_frag_in_regions  Log_unique_nr_frag  \
# timecourse_TCAATTGCTCCTGAGT                         3350            3.764699
# timecourse_TGAACCGACTATCCTG                         5182            3.931000
# timecourse_GGATTAGTGGCTTTAA                        11197            4.310375
# timecourse_AAGCCTAACTAATCAG                        19777            4.477411
# timecourse_GGCGGTTACCTGGATG                         4457            3.860398
# ...                                                  ...                 ...
# cocultured28_GATGAAGGAGGCCCTT                       1164            3.312177
# cocultured28_CTGTATTGATCCTAAT                       2166            3.515609
# cocultured28_CCTAAGCCTTGAGGTA                       2706            3.605089
# cocultured28_TCCACAATGCGTGATT                       1345            3.323458
# cocultured28_GTGCGAGTGCAAGCTT                       1268            3.316390
#
#                               cisTopic_nr_acc cisTopic_log_nr_frag  ...  \
# timecourse_TCAATTGCTCCTGAGT              4223             3.641375  ...
# timecourse_TGAACCGACTATCCTG              6382             3.832126  ...
# timecourse_GGATTAGTGGCTTTAA             12398             4.125091  ...
# timecourse_AAGCCTAACTAATCAG             18769             4.319398  ...
# timecourse_GGCGGTTACCTGGATG              5296             3.745387  ...
# ...                                       ...                  ...  ...
# cocultured28_GATGAAGGAGGCCCTT            1329             3.139564  ...
# cocultured28_CTGTATTGATCCTAAT            2482             3.412293  ...
# cocultured28_CCTAAGCCTTGAGGTA            2980             3.501196  ...
# cocultured28_TCCACAATGCGTGATT            1653             3.228657  ...
# cocultured28_GTGCGAGTGCAAGCTT            1538             3.201397  ...
#
#                                wsnn_res.10  wsnn_res.12  wsnn_res.14  \
# timecourse_TCAATTGCTCCTGAGT             49           50           47
# timecourse_TGAACCGACTATCCTG             32           26           23
# timecourse_GGATTAGTGGCTTTAA             40            8           61
# timecourse_AAGCCTAACTAATCAG             97          105          113
# timecourse_GGCGGTTACCTGGATG             37           22           70
# ...                                    ...          ...          ...
# cocultured28_GATGAAGGAGGCCCTT          108          127          132
# cocultured28_CTGTATTGATCCTAAT           43           29           21
# cocultured28_CCTAAGCCTTGAGGTA           14           55           49
# cocultured28_TCCACAATGCGTGATT           61           62           57
# cocultured28_GTGCGAGTGCAAGCTT           61           62           57
#
#                                wsnn_res.16 wsnn_res.18  wsnn_res.20  \
# timecourse_TCAATTGCTCCTGAGT             34         147          151
# timecourse_TGAACCGACTATCCTG             14          62           50
# timecourse_GGATTAGTGGCTTTAA             50          36           21
# timecourse_AAGCCTAACTAATCAG            114         125          115
# timecourse_GGCGGTTACCTGGATG             48         143          156
# ...                                    ...         ...          ...
# cocultured28_GATGAAGGAGGCCCTT          148         157          164
# cocultured28_CTGTATTGATCCTAAT           45          73           48
# cocultured28_CCTAAGCCTTGAGGTA           94          80           90
# cocultured28_TCCACAATGCGTGATT          134         129          136
# cocultured28_GTGCGAGTGCAAGCTT          142         152          123
#
#                                celltype_wnn           barcode     sample_id  \
# timecourse_TCAATTGCTCCTGAGT         hiPSC-2  TCAATTGCTCCTGAGT    timecourse
# timecourse_TGAACCGACTATCCTG     diff-neuron  TGAACCGACTATCCTG    timecourse
# timecourse_GGATTAGTGGCTTTAA         hiPSC-1  GGATTAGTGGCTTTAA    timecourse
# timecourse_AAGCCTAACTAATCAG         hiPSC-2  AAGCCTAACTAATCAG    timecourse
# timecourse_GGCGGTTACCTGGATG        diff-NPC  GGCGGTTACCTGGATG    timecourse
# ...                                     ...               ...           ...
# cocultured28_GATGAAGGAGGCCCTT      neuron-3  GATGAAGGAGGCCCTT  cocultured28
# cocultured28_CTGTATTGATCCTAAT      neuron-3  CTGTATTGATCCTAAT  cocultured28
# cocultured28_CCTAAGCCTTGAGGTA      neuron-2  CCTAAGCCTTGAGGTA  cocultured28
# cocultured28_TCCACAATGCGTGATT      neuron-3  TCCACAATGCGTGATT  cocultured28
# cocultured28_GTGCGAGTGCAAGCTT      neuron-3  GTGCGAGTGCAAGCTT  cocultured28
#
#                                                 long_barcode
# timecourse_TCAATTGCTCCTGAGT      timecourse_TCAATTGCTCCTGAGT
# timecourse_TGAACCGACTATCCTG      timecourse_TGAACCGACTATCCTG
# timecourse_GGATTAGTGGCTTTAA      timecourse_GGATTAGTGGCTTTAA
# timecourse_AAGCCTAACTAATCAG      timecourse_AAGCCTAACTAATCAG
# timecourse_GGCGGTTACCTGGATG      timecourse_GGCGGTTACCTGGATG
# ...                                                      ...
# cocultured28_GATGAAGGAGGCCCTT  cocultured28_GATGAAGGAGGCCCTT
# cocultured28_CTGTATTGATCCTAAT  cocultured28_CTGTATTGATCCTAAT
# cocultured28_CCTAAGCCTTGAGGTA  cocultured28_CCTAAGCCTTGAGGTA
# cocultured28_TCCACAATGCGTGATT  cocultured28_TCCACAATGCGTGATT
# cocultured28_GTGCGAGTGCAAGCTT  cocultured28_GTGCGAGTGCAAGCTT
#
# [19827 rows x 70 columns]

# %%
# Select the optimal gene names host
ensembl_version_dict = {'105': 'http://www.ensembl.org',
                        '104': 'http://may2021.archive.ensembl.org/',
                        '103': 'http://feb2021.archive.ensembl.org/',
                        '102': 'http://nov2020.archive.ensembl.org/',
                        '101': 'http://aug2020.archive.ensembl.org/',
                        '100': 'http://apr2020.archive.ensembl.org/',
                        '99': 'http://jan2020.archive.ensembl.org/',
                        '98': 'http://sep2019.archive.ensembl.org/',
                        '97': 'http://jul2019.archive.ensembl.org/',
                        '96': 'http://apr2019.archive.ensembl.org/',
                        '95': 'http://jan2019.archive.ensembl.org/',
                        '94': 'http://oct2018.archive.ensembl.org/',
                        '93': 'http://jul2018.archive.ensembl.org/',
                        '92': 'http://apr2018.archive.ensembl.org/',
                        '91': 'http://dec2017.archive.ensembl.org/',
                        '90': 'http://aug2017.archive.ensembl.org/',
                        '89': 'http://may2017.archive.ensembl.org/',
                        '88': 'http://mar2017.archive.ensembl.org/',
                        '87': 'http://dec2016.archive.ensembl.org/',
                        '86': 'http://oct2016.archive.ensembl.org/',
                        '80': 'http://may2015.archive.ensembl.org/',
                        '77': 'http://oct2014.archive.ensembl.org/',
                        '75': 'http://feb2014.archive.ensembl.org/',
                        '54': 'http://may2009.archive.ensembl.org/'}

import pybiomart as pbm
def test_ensembl_host(scplus_obj, host, species):
    dataset = pbm.Dataset(name=species+'_gene_ensembl',  host=host)
    annot = dataset.query(attributes=['chromosome_name', 'transcription_start_site', 'strand', 'external_gene_name', 'transcript_biotype'])
    annot.columns = ['Chromosome', 'Start', 'Strand', 'Gene', 'Transcript_type']
    annot['Chromosome'] = annot['Chromosome'].astype('str')
    filter = annot['Chromosome'].str.contains('CHR|GL|JH|MT')
    annot = annot[~filter]
    annot.columns=['Chromosome', 'Start', 'Strand', 'Gene', 'Transcript_type']
    gene_names_release = set(annot['Gene'].tolist())
    #print(gene_names_release)[1:5]
    #print(scplus_obj.gene_names)[1:5]
    print(len(list(set(gene_names_release) & set(scplus_obj.gene_names))) > 0)
    ov=len([x for x in scplus_obj.gene_names if x in gene_names_release])
    print('Genes recovered: ' + str(ov) + ' out of ' + str(len(scplus_obj.gene_names)))
    return ov

n_overlap = {}
for version in ensembl_version_dict.keys():
    print(f'host: {version}')
    try:
        n_overlap[version] =  test_ensembl_host(scplus_obj, ensembl_version_dict[version], 'hsapiens')
    except:
        print('Host not reachable')
v = sorted(n_overlap.items(), key=lambda item: item[1], reverse=True)[0][0]
print(f"version: {v} has the largest overlap, use {ensembl_version_dict[v]} as biomart host")
# Out:
# host: 105
# True
# Genes recovered: 20796 out of 30768
# host: 104
# True
# Genes recovered: 21035 out of 30768
# host: 103
# True
# Genes recovered: 30007 out of 30768
# host: 102
# True
# Genes recovered: 30078 out of 30768
# host: 101
# True
# Genes recovered: 30194 out of 30768
# host: 100
# True
# Genes recovered: 30378 out of 30768
# host: 99
# True
# Genes recovered: 30461 out of 30768
# host: 98
# True
# Genes recovered: 30745 out of 30768
# host: 97
# True
# Genes recovered: 30345 out of 30768
# host: 96
# True
# Genes recovered: 28859 out of 30768
# host: 95
# True
# Genes recovered: 28591 out of 30768
# host: 94
# True
# Genes recovered: 28508 out of 30768
# host: 93
# True
# Genes recovered: 28203 out of 30768
# host: 92
# True
# Genes recovered: 28094 out of 30768
# host: 91
# Host not reachable
# host: 90
# Host not reachable
# host: 89
# Host not reachable
# host: 88
# Host not reachable
# host: 87
# Host not reachable
# host: 86
# Host not reachable
# host: 80
# True
# Genes recovered: 20176 out of 30768
# host: 77
# True
# Genes recovered: 19803 out of 30768
# host: 75
# Host not reachable
# host: 54
# Host not reachable
# version: 98 has the largest overlap, use http://sep2019.archive.ensembl.org/ as biomart host

# %%
# Choose the best host
biomart_host = "http://sep2019.archive.ensembl.org/"

# %%
# Before running  also download a list of known human TFs from the human transcription factors database
# !wget -O /g/scb/zaugg/deuner/SCENIC+/inputdata/utoronto_human_tfs_v_1.01.txt  http://humantfs.ccbr.utoronto.ca/download/v_1.01/TF_names_v_1.01.txt
# Out:
# --2023-05-28 10:50:58--  http://humantfs.ccbr.utoronto.ca/download/v_1.01/TF_names_v_1.01.txt
# Resolving humantfs.ccbr.utoronto.ca (humantfs.ccbr.utoronto.ca)... 142.150.52.218
# Connecting to humantfs.ccbr.utoronto.ca (humantfs.ccbr.utoronto.ca)|142.150.52.218|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11838 (12K) [text/plain]
# Saving to: ‘/g/scb/zaugg/deuner/SCENIC+/inputdata/utoronto_human_tfs_v_1.01.txt’
#
# /g/scb/zaugg/deuner 100%[===================>]  11.56K  --.-KB/s    in 0.1s
#
# 2023-05-28 10:50:59 (107 KB/s) - ‘/g/scb/zaugg/deuner/SCENIC+/inputdata/utoronto_human_tfs_v_1.01.txt’ saved [11838/11838]

# %%
# Also download a the program bedToBigBed this will be used to generate files which can be uploaded to the UCSC genome browser
# !wget -O /g/scb/zaugg/deuner/SCENIC+/inputdata/bedToBigBed http://hgdownload.soe.ucsc.edu/admin/exe/linux.x86_64/bedToBigBed
# !chmod +x /g/scb/zaugg/deuner/SCENIC+/inputdata/bedToBigBed
# Out:
# --2023-05-28 10:51:01--  http://hgdownload.soe.ucsc.edu/admin/exe/linux.x86_64/bedToBigBed
# Resolving hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)... 128.114.119.163
# Connecting to hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)|128.114.119.163|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9631544 (9.2M)
# Saving to: ‘/g/scb/zaugg/deuner/SCENIC+/inputdata/bedToBigBed’
#
# /g/scb/zaugg/deuner 100%[===================>]   9.18M  5.09MB/s    in 1.8s
#
# 2023-05-28 10:51:03 (5.09 MB/s) - ‘/g/scb/zaugg/deuner/SCENIC+/inputdata/bedToBigBed’ saved [9631544/9631544]

# %%
#only keep the first two columns of the PCA embedding in order to be able to visualize this in SCope
#scplus_obj.dr_cell['GEX_X_pca'] = scplus_obj.dr_cell['GEX_X_pca'].iloc[:, 0:2]
#scplus_obj.dr_cell['GEX_rep'] = scplus_obj.dr_cell['GEX_rep'].iloc[:, 0:2]

# %%
# import ray
# ray.shutdown()
# ray.init()

# %%
# Run the analysis
from scenicplus.wrappers.run_scenicplus import run_scenicplus
# try:
run_scenicplus(
        scplus_obj = scplus_obj,
        variable = ['GEX_celltype'],
        species = 'hsapiens',
        assembly = 'hg38',
        tf_file = '/g/scb/zaugg/deuner/SCENIC+/inputdata/utoronto_human_tfs_v_1.01.txt',
        save_path = os.path.join(tmp_dir, 'scenicplus'),
        biomart_host = biomart_host,
        upstream = [1000, 150000],
        downstream = [1000, 150000],
        calculate_TF_eGRN_correlation = True,
        calculate_DEGs_DARs = True,
        export_to_loom_file = True,
        export_to_UCSC_file = True,
        path_bedToBigBed = '/g/scb/zaugg/deuner/SCENIC+/inputdata',
        n_cpu = 24,
        _temp_dir = None)#'/g/scb/zaugg/deuner/ray_spill')
# except Exception as e:
#     #in case of failure, still save the object
#     dill.dump(scplus_obj, open(os.path.join(out_dir, '/scplus_obj.pkl'), 'wb'), protocol=-1)
#     raise(e)
# Out:
# 2023-05-28 10:52:02,246 SCENIC+_wrapper INFO     /g/scb/zaugg/deuner/SCENIC+/tmp/combined/scenicplus folder already exists.
# 2023-05-28 10:52:02,247 SCENIC+_wrapper INFO     Merging cistromes
# 2023-05-28 11:02:06,754 SCENIC+_wrapper INFO     Getting search space
# 2023-05-28 11:02:08,809 R2G          INFO     Downloading gene annotation from biomart dataset: hsapiens_gene_ensembl
# 2023-05-28 11:02:21,881 R2G          INFO     Downloading chromosome sizes from: http://hgdownload.cse.ucsc.edu/goldenPath/hg38/bigZips/hg38.chrom.sizes
# 2023-05-28 11:02:23,324 R2G          INFO     Extending promoter annotation to 10 bp upstream and 10 downstream
# 2023-05-28 11:02:42,457 R2G          INFO     Extending search space to:
#             						150000 bp downstream of the end of the gene.
#             						150000 bp upstream of the start of the gene.
# 2023-05-28 11:03:11,011 R2G          INFO     Intersecting with regions.
# join: Strand data from other will be added as strand data to self.
# If this is undesired use the flag apply_strand_suffix=False.
# To turn off the warning set apply_strand_suffix to True or False.
# 2023-05-28 11:03:12,322 R2G          INFO     Calculating distances from region to gene
# 2023-05-28 11:08:23,454 R2G          INFO     Imploding multiple entries per region and gene
# 2023-05-28 11:17:36,574 R2G          INFO     Done!
# 2023-05-28 11:17:37,334 SCENIC+_wrapper INFO     Inferring region to gene relationships
# 2023-05-28 11:17:37,976 R2G          INFO     Calculating region to gene importances, using GBM method
# 2023-05-28 11:17:55,147	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# initializing: 100%|███████████████████████| 17522/17522 [38:30<00:00,  7.58it/s]
# Running using 24 cores: 100%|█████████████| 17522/17522 [10:29<00:00, 27.82it/s]
# 2023-05-28 12:07:17,334 R2G          INFO     Took 2979.356848716736 seconds
# 2023-05-28 12:07:17,338 R2G          INFO     Calculating region to gene correlation, using SR method
# 2023-05-28 12:07:35,686	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# initializing:   2%|▍                        | 291/17522 [00:39<39:10,  7.33it/s](_score_regions_to_single_gene_ray pid=1762371) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762371)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:   4%|▉                        | 680/17522 [01:27<35:08,  7.99it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:   4%|█                        | 724/17522 [01:33<34:01,  8.23it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:   8%|█▊                      | 1357/17522 [02:52<32:10,  8.38it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:   8%|█▉                      | 1411/17522 [02:58<32:52,  8.17it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:   8%|█▉                      | 1417/17522 [02:59<32:15,  8.32it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:   9%|██                      | 1496/17522 [03:09<32:15,  8.28it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:   9%|██▎                     | 1662/17522 [03:30<30:38,  8.62it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  11%|██▋                     | 1935/17522 [04:03<32:12,  8.07it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  13%|███                     | 2216/17522 [04:38<31:50,  8.01it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  13%|███                     | 2234/17522 [04:40<31:54,  7.98it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  13%|███▏                    | 2293/17522 [04:47<30:40,  8.27it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  13%|███▏                    | 2365/17522 [04:56<30:34,  8.26it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  16%|███▊                    | 2761/17522 [05:45<29:41,  8.28it/s](_score_regions_to_single_gene_ray pid=1762406) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762406)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  17%|████                    | 2932/17522 [06:06<30:13,  8.05it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  25%|█████▉                  | 4311/17522 [08:56<26:05,  8.44it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  25%|█████▉                  | 4341/17522 [08:59<26:37,  8.25it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  25%|██████                  | 4437/17522 [09:11<25:51,  8.43it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  25%|██████                  | 4452/17522 [09:13<27:13,  8.00it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  26%|██████▏                 | 4547/17522 [09:25<27:17,  7.92it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  26%|██████▏                 | 4551/17522 [09:25<27:10,  7.96it/s](_score_regions_to_single_gene_ray pid=1762406) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762406)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  26%|██████▎                 | 4606/17522 [09:32<26:48,  8.03it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  27%|██████▍                 | 4661/17522 [09:39<27:46,  7.72it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  27%|██████▍                 | 4735/17522 [10:11<26:55,  7.92it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  30%|███████                 | 5187/17522 [11:08<24:25,  8.41it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  30%|███████                 | 5198/17522 [11:09<25:57,  7.91it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  31%|███████▍                | 5386/17522 [11:32<25:23,  7.97it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  33%|███████▊                | 5695/17522 [12:11<24:35,  8.02it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  33%|███████▊                | 5739/17522 [12:16<25:19,  7.75it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  33%|███████▉                | 5820/17522 [12:26<24:16,  8.03it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  34%|████████▏               | 5981/17522 [12:46<23:20,  8.24it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  36%|████████▌               | 6244/17522 [13:19<23:27,  8.01it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  37%|████████▊               | 6435/17522 [13:42<22:04,  8.37it/s](_score_regions_to_single_gene_ray pid=1762406) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762406)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  37%|████████▉               | 6546/17522 [13:56<20:46,  8.80it/s](_score_regions_to_single_gene_ray pid=1762406) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762406)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  39%|█████████▎              | 6775/17522 [14:24<22:15,  8.05it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  43%|██████████▍             | 7605/17522 [16:06<19:55,  8.29it/s](_score_regions_to_single_gene_ray pid=1762406) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762406)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  44%|██████████▌             | 7718/17522 [16:19<19:48,  8.25it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  46%|███████████             | 8033/17522 [16:58<19:03,  8.30it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  50%|███████████▉            | 8706/17522 [18:21<17:26,  8.43it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  50%|████████████            | 8764/17522 [18:28<18:15,  8.00it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  50%|████████████            | 8771/17522 [18:29<18:12,  8.01it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  50%|████████████            | 8827/17522 [18:36<18:02,  8.03it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  51%|████████████▏           | 8891/17522 [18:44<17:41,  8.13it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  52%|████████████▍           | 9112/17522 [19:11<17:18,  8.10it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  52%|████████████▌           | 9184/17522 [19:20<16:51,  8.24it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  54%|████████████▉           | 9434/17522 [20:21<17:41,  7.62it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  54%|████████████▉           | 9450/17522 [20:23<16:59,  7.91it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  55%|█████████████           | 9552/17522 [20:36<17:08,  7.75it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  55%|█████████████▎          | 9706/17522 [20:56<16:19,  7.98it/s](_score_regions_to_single_gene_ray pid=1762406) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762406)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  58%|█████████████▎         | 10152/17522 [21:51<15:16,  8.04it/s](_score_regions_to_single_gene_ray pid=1762406) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762406)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  59%|█████████████▌         | 10295/17522 [22:09<14:48,  8.13it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  60%|█████████████▊         | 10520/17522 [22:37<14:11,  8.22it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  60%|█████████████▉         | 10593/17522 [22:46<14:54,  7.75it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  62%|██████████████▎        | 10879/17522 [23:21<12:56,  8.56it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  63%|██████████████▍        | 11042/17522 [23:41<13:12,  8.18it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  63%|██████████████▌        | 11114/17522 [23:50<12:27,  8.57it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  65%|███████████████        | 11475/17522 [24:34<12:19,  8.18it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  70%|███████████████▉       | 12185/17522 [26:01<10:14,  8.69it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  71%|████████████████▎      | 12433/17522 [26:31<10:21,  8.19it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  72%|████████████████▌      | 12601/17522 [26:51<09:48,  8.36it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  72%|████████████████▌      | 12629/17522 [26:55<09:51,  8.27it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  73%|████████████████▋      | 12754/17522 [27:10<09:52,  8.05it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  73%|████████████████▊      | 12794/17522 [27:15<09:46,  8.06it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  75%|█████████████████▏     | 13124/17522 [27:55<08:50,  8.30it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  75%|█████████████████▎     | 13207/17522 [28:05<08:45,  8.21it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  75%|█████████████████▎     | 13223/17522 [28:07<08:56,  8.01it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  76%|█████████████████▌     | 13358/17522 [28:24<08:08,  8.53it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  78%|█████████████████▉     | 13629/17522 [28:57<07:58,  8.14it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  78%|█████████████████▉     | 13677/17522 [29:03<07:44,  8.27it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  79%|██████████████████     | 13766/17522 [29:14<07:31,  8.31it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  83%|███████████████████▏   | 14601/17522 [31:20<06:11,  7.86it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  84%|███████████████████▎   | 14743/17522 [31:37<05:54,  7.84it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  85%|███████████████████▌   | 14886/17522 [31:55<05:23,  8.14it/s](_score_regions_to_single_gene_ray pid=1762406) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762406)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  85%|███████████████████▌   | 14920/17522 [31:59<05:18,  8.16it/s](_score_regions_to_single_gene_ray pid=1762406) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762406)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  86%|███████████████████▋   | 15012/17522 [32:10<05:06,  8.19it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  89%|████████████████████▍  | 15612/17522 [33:24<03:42,  8.59it/s](_score_regions_to_single_gene_ray pid=1762348) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762348)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  90%|████████████████████▋  | 15772/17522 [33:43<03:24,  8.54it/s](_score_regions_to_single_gene_ray pid=1762379) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762379)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  91%|████████████████████▉  | 15975/17522 [34:08<03:09,  8.15it/s](_score_regions_to_single_gene_ray pid=1762352) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762352)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  96%|██████████████████████ | 16822/17522 [35:52<01:23,  8.35it/s](_score_regions_to_single_gene_ray pid=1762368) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762368)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing:  96%|██████████████████████▏| 16887/17522 [36:01<01:19,  8.02it/s](_score_regions_to_single_gene_ray pid=1762362) /g/scb/zaugg/deuner/miniconda3/envs/scenicplus/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4921: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# (_score_regions_to_single_gene_ray pid=1762362)   warnings.warn(stats.ConstantInputWarning(warn_msg))
# initializing: 100%|███████████████████████| 17522/17522 [37:20<00:00,  7.82it/s]
# Running using 24 cores: 100%|████████████| 17522/17522 [01:08<00:00, 257.56it/s]
# 2023-05-28 12:46:23,040 R2G          INFO     Took 2345.7002811431885 seconds
# 2023-05-28 12:46:38,601 R2G          INFO     Done!
# 2023-05-28 12:46:39,030 SCENIC+_wrapper INFO     Inferring TF to gene relationships
# 2023-05-28 12:46:59,828	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2023-05-28 12:47:13,358 TF2G         INFO     Calculating TF to gene correlation, using GBM method
# initializing:   1%|▏                      | 213/30768 [03:24<4:42:22,  1.80it/s](raylet) Spilled 4837 MiB, 2 objects, write throughput 474 MiB/s. Set RAY_verbose_spill_logs=0 to disable this message.
# (raylet) Spilled 9675 MiB, 5 objects, write throughput 858 MiB/s.
# (raylet) Spilled 19351 MiB, 11 objects, write throughput 1327 MiB/s.
# (raylet) Spilled 24188 MiB, 14 objects, write throughput 1536 MiB/s.
# initializing:   1%|▏                      | 235/30768 [03:50<2:44:39,  3.09it/s](raylet) Spilled 53216 MiB, 33 objects, write throughput 1728 MiB/s.
# (raylet) [2023-05-28 12:51:06,022 E 1973851 1973874] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-05-28_12-46-41_694128_1511726 is over 95% full, available space: 5491822592; capacity: 129866661888. Object creation will fail if spilling is required.
# initializing:   1%|▏                      | 243/30768 [03:55<3:10:28,  2.67it/s](raylet) [2023-05-28 12:51:16,042 E 1973851 1973874] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-05-28_12-46-41_694128_1511726 is over 95% full, available space: 5073223680; capacity: 129866661888. Object creation will fail if spilling is required.
# (raylet) [2023-05-28 12:51:26,057 E 1973851 1973874] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-05-28_12-46-41_694128_1511726 is over 95% full, available space: 5073223680; capacity: 129866661888. Object creation will fail if spilling is required.
# initializing:   1%|▏                      | 258/30768 [04:21<3:34:45,  2.37it/s](raylet) [2023-05-28 12:51:36,072 E 1973851 1973874] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-05-28_12-46-41_694128_1511726 is over 95% full, available space: 5073223680; capacity: 129866661888. Object creation will fail if spilling is required.
# initializing:   1%|▏                      | 260/30768 [04:23<6:01:19,  1.41it/s](raylet) [2023-05-28 12:51:46,090 E 1973851 1973874] (raylet) file_system_monitor.cc:105: /tmp/ray/session_2023-05-28_12-46-41_694128_1511726 is over 95% full, available space: 5073199104; capacity: 129866661888. Object creation will fail if spilling is required.
# initializing:   1%|▏                      | 261/30768 [04:41<9:08:43,  1.08s/it]
# Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# 2023-05-28 12:52:47,860 TF2G         INFO     Took 334.49985218048096 seconds
# 2023-05-28 12:52:47,861 TF2G         INFO     Adding correlation coefficients to adjacencies.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[17], line 4
#       2 from scenicplus.wrappers.run_scenicplus import run_scenicplus
#       3 # try:
# ----> 4 run_scenicplus(
#       5         scplus_obj = scplus_obj,
#       6         variable = ['GEX_celltype'],
#       7         species = 'hsapiens',
#       8         assembly = 'hg38',
#       9         tf_file = '/g/scb/zaugg/deuner/SCENIC+/inputdata/utoronto_human_tfs_v_1.01.txt',
#      10         save_path = os.path.join(tmp_dir, 'scenicplus'),
#      11         biomart_host = biomart_host,
#      12         upstream = [1000, 150000],
#      13         downstream = [1000, 150000],
#      14         calculate_TF_eGRN_correlation = True,
#      15         calculate_DEGs_DARs = True,
#      16         export_to_loom_file = True,
#      17         export_to_UCSC_file = True,
#      18         path_bedToBigBed = '/g/scb/zaugg/deuner/SCENIC+/inputdata',
#      19         n_cpu = 24,
#      20         _temp_dir = None)
#
# File /g/scb/zaugg/deuner/SCENIC+/scenicplus/src/scenicplus/wrappers/run_scenicplus.py:151, in run_scenicplus(scplus_obj, variable, species, assembly, tf_file, save_path, biomart_host, upstream, downstream, region_ranking, gene_ranking, simplified_eGRN, calculate_TF_eGRN_correlation, calculate_DEGs_DARs, export_to_loom_file, export_to_UCSC_file, tree_structure, path_bedToBigBed, n_cpu, _temp_dir, **kwargs)
#     149 if 'TF2G_adj' not in scplus_obj.uns.keys():
#     150     log.info('Inferring TF to gene relationships')
# --> 151     calculate_TFs_to_genes_relationships(scplus_obj,
#     152                     tf_file = tf_file,
#     153                     ray_n_cpu = n_cpu,
#     154                     method = 'GBM',
#     155                     _temp_dir = _temp_dir,
#     156                     key= 'TF2G_adj',
#     157                     **kwargs)
#     159 if 'eRegulons' not in scplus_obj.uns.keys():
#     160     log.info('Build eGRN')
#
# File /g/scb/zaugg/deuner/SCENIC+/scenicplus/src/scenicplus/TF_to_gene.py:332, in calculate_TFs_to_genes_relationships(scplus_obj, tf_file, method, ray_n_cpu, key, **kwargs)
#     330 start_time = time.time()
#     331 log.info(f'Adding correlation coefficients to adjacencies.')
# --> 332 adj = pd.concat(tfs_to_genes).sort_values(by='importance', ascending=False)
#     333 ex_matrix = pd.DataFrame(
#     334     scplus_obj.X_EXP, index=scplus_obj.cell_names, columns=scplus_obj.gene_names)
#     335 adj = _add_correlation(adj, ex_matrix)
#
# UnboundLocalError: local variable 'tfs_to_genes' referenced before assignment

# %% [markdown]
# ## Downstream Analysis

# %% [markdown]
# ### Simplifying and filtering SCENIC+ output

# %%
from scenicplus.preprocessing.filtering import apply_std_filtering_to_eRegulons
apply_std_filtering_to_eRegulons(scplus_obj)

# %%
scplus_obj.uns['eRegulon_metadata_filtered'].head()

# %% [markdown]
# ### eRegulon enrichment scores

# %%
from scenicplus.eregulon_enrichment import score_eRegulons
region_ranking = dill.load(open(os.path.join(out_dir, 'scenicplus/region_ranking.pkl'), 'rb')) #load ranking calculated using the wrapper function
gene_ranking = dill.load(open(os.path.join(out_dir, 'scenicplus/gene_ranking.pkl'), 'rb')) #load ranking calculated using the wrapper function
score_eRegulons(scplus_obj,
                ranking = region_ranking,
                eRegulon_signatures_key = 'eRegulon_signatures_filtered',
                key_added = 'eRegulon_AUC_filtered',
                enrichment_type= 'region',
                auc_threshold = 0.05,
                normalize = False,
                n_cpu = 5)
score_eRegulons(scplus_obj,
                gene_ranking,
                eRegulon_signatures_key = 'eRegulon_signatures_filtered',
                key_added = 'eRegulon_AUC_filtered',
                enrichment_type = 'gene',
                auc_threshold = 0.05,
                normalize= False,
                n_cpu = 5)

# %% [markdown]
# ### eRegulon dimensionality reduction

# %%
from scenicplus.dimensionality_reduction import run_eRegulons_tsne, run_eRegulons_umap
run_eRegulons_umap(
    scplus_obj = scplus_obj,
    auc_key = 'eRegulon_AUC_filtered',
    reduction_name = 'eRegulons_UMAP', #overwrite previously calculated UMAP
)
run_eRegulons_tsne(
    scplus_obj = scplus_obj,
    auc_key = 'eRegulon_AUC_filtered',
    reduction_name = 'eRegulons_tSNE', #overwrite previously calculated tSNE
)

# %%
# Visualize it
from scenicplus.dimensionality_reduction import plot_metadata_given_ax
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#specify color_dictionary

color_dict = {
    'neuron': "#065143",
    'hiPSC': "#70B77E",
    'microglia': "#E0A890",
    'diff.state': "#053C5E" 
}

fig, axs = plt.subplots(ncols=2, figsize = (16, 8))
plot_metadata_given_ax(
    scplus_obj=scplus_obj,
    ax = axs[0],
    reduction_name = 'eRegulons_UMAP',
    variable = 'GEX_celltype', #note the GEX_ prefix, this metadata originated from the gene expression metadata (on which we did the cell type annotation before)
    color_dictionary={'GEX_celltype': color_dict}
)
plot_metadata_given_ax(
    scplus_obj=scplus_obj,
    ax = axs[1],
    reduction_name = 'eRegulons_tSNE',
    variable = 'GEX_celltype', #note the GEX_ prefix, this metadata originated from the gene expression metadata (on which we did the cell type annotation before)
    color_dictionary={'GEX_celltype': color_dict}
)
fig.tight_layout()
sns.despine(ax = axs[0]) #remove top and right edge of axis border
sns.despine(ax = axs[1]) #remove top and right edge of axis border
plt.show()

# %% [markdown]
# ### plot the activity / expression of an eRegulon on the dimensionality reduction

# %%
from scenicplus.dimensionality_reduction import plot_eRegulon
plot_eRegulon(
    scplus_obj = scplus_obj,
    reduction_name = 'eRegulons_tSNE',
    selected_regulons = ['POU4F3', 'KLF12', 'POU4F1', 'CUX2', 'ONECUT3'],
    scale = True,
    auc_key = 'eRegulon_AUC_filtered')

# %% [markdown]
# ### dotplot-heatmap

# %%
# We first generate pseudobulk gene expression and region accessibility data, per celltype, to limit the amount of noise for the correlation calculation.
from scenicplus.cistromes import TF_cistrome_correlation, generate_pseudobulks

generate_pseudobulks(
        scplus_obj = scplus_obj,
        variable = 'GEX_celltype',
        auc_key = 'eRegulon_AUC_filtered',
        signature_key = 'Gene_based')
generate_pseudobulks(
        scplus_obj = scplus_obj,
        variable = 'GEX_celltype',
        auc_key = 'eRegulon_AUC_filtered',
        signature_key = 'Region_based')

TF_cistrome_correlation(
            scplus_obj,
            use_pseudobulk = True,
            variable = 'GEX_celltype',
            auc_key = 'eRegulon_AUC_filtered',
            signature_key = 'Gene_based',
            out_key = 'filtered_gene_based')
TF_cistrome_correlation(
            scplus_obj,
            use_pseudobulk = True,
            variable = 'GEX_celltype',
            auc_key = 'eRegulon_AUC_filtered',
            signature_key = 'Region_based',
            out_key = 'filtered_region_based')

# %%
scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based'].head()

# %%
# Let's visualize these correlations in a scatter plot and select eRegulons for which the correlaiton coefficient is above 0.70 or below -0.75
import numpy as np
n_targets = [int(x.split('(')[1].replace('r)', '')) for x in scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Cistrome']]
rho = scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Rho'].to_list()
adj_pval = scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Adjusted_p-value'].to_list()

thresholds = {
        'rho': [-0.75, 0.70],
        'n_targets': 0
}
import seaborn as sns
fig, ax = plt.subplots(figsize = (10, 5))
sc = ax.scatter(rho, n_targets, c = -np.log10(adj_pval), s = 5)
ax.set_xlabel('Correlation coefficient')
ax.set_ylabel('nr. target regions')
#ax.hlines(y = thresholds['n_targets'], xmin = min(rho), xmax = max(rho), color = 'black', ls = 'dashed', lw = 1)
ax.vlines(x = thresholds['rho'], ymin = 0, ymax = max(n_targets), color = 'black', ls = 'dashed', lw = 1)
ax.text(x = thresholds['rho'][0], y = max(n_targets), s = str(thresholds['rho'][0]))
ax.text(x = thresholds['rho'][1], y = max(n_targets), s = str(thresholds['rho'][1]))
sns.despine(ax = ax)
fig.colorbar(sc, label = '-log10(adjusted_pvalue)', ax = ax)
plt.show()

# %%
selected_cistromes = scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based'].loc[
        np.logical_or(
                scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Rho'] > thresholds['rho'][1],
                scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Rho'] < thresholds['rho'][0]
        )]['Cistrome'].to_list()
selected_eRegulons = [x.split('_(')[0] for x in selected_cistromes]
selected_eRegulons_gene_sig = [
        x for x in scplus_obj.uns['eRegulon_signatures_filtered']['Gene_based'].keys()
        if x.split('_(')[0] in selected_eRegulons]
selected_eRegulons_region_sig = [
        x for x in scplus_obj.uns['eRegulon_signatures_filtered']['Region_based'].keys()
        if x.split('_(')[0] in selected_eRegulons]
#save the results in the scenicplus object
scplus_obj.uns['selected_eRegulon'] = {'Gene_based': selected_eRegulons_gene_sig, 'Region_based': selected_eRegulons_region_sig}
print(f'selected: {len(selected_eRegulons_gene_sig)} eRegulons')

# %%
# Save these changes we have made to the scenicplus_obj
dill.dump(scplus_obj, open(os.path.join(out_dir, 'scenicplus/scplus_obj.pkl'), 'wb'), protocol=-1)

# %%
# Plot the heatmap-dotplot
from scenicplus.plotting.dotplot import heatmap_dotplot
heatmap_dotplot(
        scplus_obj = scplus_obj,
        size_matrix = scplus_obj.uns['eRegulon_AUC_filtered']['Region_based'], #specify what to plot as dot sizes, target region enrichment in this case
        color_matrix = scplus_obj.to_df('EXP'), #specify  what to plot as colors, TF expression in this case
        scale_size_matrix = True,
        scale_color_matrix = True,
        group_variable = 'GEX_celltype',
        subset_eRegulons = scplus_obj.uns['selected_eRegulon']['Gene_based'],
        figsize = (5, 20),
        orientation = 'vertical')

# %% [markdown]
# ### Overlap of predicted target regions

# %%
# calculate the RSS for the target regions of the selected eRegulons.
from scenicplus.RSS import *
regulon_specificity_scores(
        scplus_obj,
        variable = 'GEX_celltype',
        auc_key = 'eRegulon_AUC_filtered',
        signature_keys = ['Region_based'],
        selected_regulons = [x for x in scplus_obj.uns['selected_eRegulon']['Region_based'] if '-' not in x],
        out_key_suffix = '_filtered')

# %%
# visualize the RSS values using a scatter plot
plot_rss(scplus_obj, 'GEX_celltype_filtered', num_columns=2, top_n=10, figsize = (5, 10))

# %%
# select the top 10 eRegulons per cell type
flat_list = lambda t: [item for sublist in t for item in sublist]
selected_markers = list(set(flat_list(
    [scplus_obj.uns['RSS']['GEX_celltype_filtered'].loc[celltype].sort_values(ascending = False).head(10).index.to_list()
    for celltype in scplus_obj.uns['RSS']['GEX_celltype_filtered'].index])))

# %%
from scenicplus.plotting.correlation_plot import *

region_intersetc_data, Z = jaccard_heatmap(
        scplus_obj,
        method = 'intersect',
        gene_or_region_based = 'Region_based',
        use_plotly = False,
        selected_regulons = selected_markers,
        signature_key = 'eRegulon_signatures_filtered',
        figsize = (10, 10), return_data = True, vmax = 0.5, cmap = 'plasma')

# %% [markdown]
# ### Plotting a Network

# %%
from pycisTopic.diff_features import find_highly_variable_features
hvr = find_highly_variable_features(scplus_obj.to_df('ACC').loc[list(set(scplus_obj.uns['eRegulon_metadata_filtered']['Region']))], n_top_features=1000, plot = False)
hvg = find_highly_variable_features(scplus_obj.to_df('EXP')[list(set(scplus_obj.uns['eRegulon_metadata_filtered']['Gene']))].T, n_top_features=1000, plot = False)

# %%
from scenicplus.networks import create_nx_tables, create_nx_graph, plot_networkx, export_to_cytoscape
nx_tables = create_nx_tables(
    scplus_obj = scplus_obj,
    eRegulon_metadata_key ='eRegulon_metadata_filtered',
    subset_eRegulons = ['PAX5', 'EBF1', 'POU2AF1'],
    subset_regions = hvr,
    subset_genes = hvg,
    add_differential_gene_expression = True,
    add_differential_region_accessibility = True,
    differential_variable = ['GEX_celltype'])

# %%
G, pos, edge_tables, node_tables = create_nx_graph(nx_tables,
                   use_edge_tables = ['TF2R','R2G'],
                   color_edge_by = {'TF2R': {'variable' : 'TF', 'category_color' : {'PAX5': 'Orange', 'EBF1': 'Purple', 'POU2AF1': 'Red'}},
                                    'R2G': {'variable' : 'R2G_rho', 'continuous_color' : 'viridis', 'v_min': -1, 'v_max': 1}},
                   transparency_edge_by =  {'R2G': {'variable' : 'R2G_importance', 'min_alpha': 0.1, 'v_min': 0}},
                   width_edge_by = {'R2G': {'variable' : 'R2G_importance', 'max_size' :  1.5, 'min_size' : 1}},
                   color_node_by = {'TF': {'variable': 'TF', 'category_color' : {'PAX5': 'Orange', 'EBF1': 'Purple', 'POU2AF1': 'Red'}},
                                    'Gene': {'variable': 'GEX_celltype_Log2FC_B_cells_1', 'continuous_color' : 'bwr'},
                                    'Region': {'variable': 'GEX_celltype_Log2FC_B_cells_1', 'continuous_color' : 'viridis'}},
                   transparency_node_by =  {'Region': {'variable' : 'GEX_celltype_Log2FC_B_cells_1', 'min_alpha': 0.1},
                                    'Gene': {'variable' : 'GEX_celltype_Log2FC_B_cells_1', 'min_alpha': 0.1}},
                   size_node_by = {'TF': {'variable': 'fixed_size', 'fixed_size': 30},
                                    'Gene': {'variable': 'fixed_size', 'fixed_size': 15},
                                    'Region': {'variable': 'fixed_size', 'fixed_size': 10}},
                   shape_node_by = {'TF': {'variable': 'fixed_shape', 'fixed_shape': 'ellipse'},
                                    'Gene': {'variable': 'fixed_shape', 'fixed_shape': 'ellipse'},
                                    'Region': {'variable': 'fixed_shape', 'fixed_shape': 'diamond'}},
                   label_size_by = {'TF': {'variable': 'fixed_label_size', 'fixed_label_size': 20.0},
                                    'Gene': {'variable': 'fixed_label_size', 'fixed_label_size': 10.0},
                                    'Region': {'variable': 'fixed_label_size', 'fixed_label_size': 0.0}},
                   layout='kamada_kawai_layout',
                   scale_position_by=250)

# %%
plt.figure(figsize=(10,10))
plot_networkx(G, pos)

# %%
export_to_cytoscape(G, pos, out_file = os.path.join(out_dir, 'scenicplus/network_combined.cys'))
