# %% [markdown]
# # SCENIC+ ANDATA OBJECT PREPARATION

# %% [markdown]
# REFERENCES:
#
# anndata object wiki = https://anndata.readthedocs.io/en/latest/index.html
#
# anndata basics = https://anndata.readthedocs.io/en/latest/tutorials/notebooks/getting-started.html
#
# scenicplus workflow = https://scenicplus.readthedocs.io/en/latest/pbmc_multiome_tutorial.html
#
# Single-cell best practices = https://www.sc-best-practices.org/cellular_structure/annotation.html

# %% [markdown]
# ## Set-up environment

# %%
# Supress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import sys
import os
_stderr = sys.stderr
null = open(os.devnull,'wb')

# Use non-corrupt UMAP version
# !pip install -q umap-learn==0.5.1

# %%
import scanpy as sc
import numpy as np
import matplotlib.pyplot as pl
from scipy import io
import pandas as pd

# %% [markdown]
# ### Store data directories

# %%
# Set up directories
sample = "timecourse"

work_dir = '/g/scb/zaugg/deuner/SCENIC+/'
indata_dir = "/g/scb/zaugg/deuner/SCENIC+/inputdata/"
seurat_dir = "/g/scb/zaugg/deuner/GRaNIE/tmp/"
outdata_dir = "/g/scb/zaugg/deuner/SCENIC+/outputdata/"
tmp_dir = "/g/scb/zaugg/deuner/SCENIC+/tmp/"
fig_dir = '/g/scb/zaugg/deuner/SCENIC+/figures/'

# %% [markdown]
# ### Import Anndata (preprocessed with Seurat)

# %%
# Load adata object
adata = sc.read(os.path.join(seurat_dir, 'timecourse.nomicro.h5ad'))

# %%
# inspect the data 
adata.obs
# Out:
#                              orig.ident  nCount_RNA  nFeature_RNA  percent.mt  \
# timecourse_AAACAGCCAGCCAGTT  timecourse      5020.0          2676    6.155378
# timecourse_AAACAGCCAGTAAAGC  timecourse      3832.0          2004    0.287056
# timecourse_AAACAGCCATAAGTCT  timecourse      7329.0          3535    1.159776
# timecourse_AAACAGCCATAGGCGA  timecourse      4511.0          2253    7.337619
# timecourse_AAACAGCCATCACAGC  timecourse     12095.0          4857    6.572964
# ...                                 ...         ...           ...         ...
# timecourse_TTTGTTGGTGAGGTAG  timecourse      5826.0          2665    5.029180
# timecourse_TTTGTTGGTGCGCGTA  timecourse     13128.0          5157    6.093845
# timecourse_TTTGTTGGTGTTGTGA  timecourse      3832.0          2250    7.489562
# timecourse_TTTGTTGGTTCCGGCT  timecourse      6420.0          3037    7.009346
# timecourse_TTTGTTGGTTTACTTG  timecourse     11224.0          4259    7.189950
#
#                              percent.ribo  nCount_SCT  nFeature_SCT  \
# timecourse_AAACAGCCAGCCAGTT      3.705179      6577.0          2676
# timecourse_AAACAGCCAGTAAAGC      0.730689      6634.0          2045
# timecourse_AAACAGCCATAAGTCT      1.132487      7330.0          3535
# timecourse_AAACAGCCATAGGCGA      1.906451      6652.0          2254
# timecourse_AAACAGCCATCACAGC      1.537826      8336.0          4694
# ...                                   ...         ...           ...
# timecourse_TTTGTTGGTGAGGTAG      0.944044      6678.0          2665
# timecourse_TTTGTTGGTGCGCGTA      1.706277      8351.0          4729
# timecourse_TTTGTTGGTGTTGTGA      3.183716      6674.0          2285
# timecourse_TTTGTTGGTTCCGGCT      1.043614      6780.0          3035
# timecourse_TTTGTTGGTTTACTTG      1.505702      8166.0          4220
#
#                             SCT_snn_res.0.5 seurat_clusters  \
# timecourse_AAACAGCCAGCCAGTT               2               3
# timecourse_AAACAGCCAGTAAAGC               5               5
# timecourse_AAACAGCCATAAGTCT               7               6
# timecourse_AAACAGCCATAGGCGA               3               3
# timecourse_AAACAGCCATCACAGC              12               8
# ...                                     ...             ...
# timecourse_TTTGTTGGTGAGGTAG               5               5
# timecourse_TTTGTTGGTGCGCGTA               9               7
# timecourse_TTTGTTGGTGTTGTGA               2               2
# timecourse_TTTGTTGGTTCCGGCT               2               2
# timecourse_TTTGTTGGTTTACTTG               2               2
#
#                              pANN_0.25_0.005_794  ... wsnn_res.20  \
# timecourse_AAACAGCCAGCCAGTT             0.084507  ...          73
# timecourse_AAACAGCCAGTAAAGC             0.183099  ...          39
# timecourse_AAACAGCCATAAGTCT             0.154930  ...          17
# timecourse_AAACAGCCATAGGCGA             0.140845  ...           1
# timecourse_AAACAGCCATCACAGC             0.028169  ...          35
# ...                                          ...  ...         ...
# timecourse_TTTGTTGGTGAGGTAG             0.070423  ...           2
# timecourse_TTTGTTGGTGCGCGTA             0.577465  ...          51
# timecourse_TTTGTTGGTGTTGTGA             0.197183  ...          92
# timecourse_TTTGTTGGTTCCGGCT             0.098592  ...          91
# timecourse_TTTGTTGGTTTACTTG             0.154930  ...           0
#
#                             SCT_nn_res.0.5                  celltype  \
# timecourse_AAACAGCCAGCCAGTT              3    diff - immature.neuron
# timecourse_AAACAGCCAGTAAAGC              9       neuron - excitatory
# timecourse_AAACAGCCATAAGTCT              7        hiPSC - start.diff
# timecourse_AAACAGCCATAGGCGA              3    diff - immature.neuron
# timecourse_AAACAGCCATCACAGC              7        hiPSC - start.diff
# ...                                    ...                       ...
# timecourse_TTTGTTGGTGAGGTAG              9       neuron - excitatory
# timecourse_TTTGTTGGTGCGCGTA             10  mature.neuron - adhesion
# timecourse_TTTGTTGGTGTTGTGA              2                      diff
# timecourse_TTTGTTGGTTCCGGCT              2                      diff
# timecourse_TTTGTTGGTTTACTTG              2                      diff
#
#                              basic_celltype  pseudotime  \
# timecourse_AAACAGCCAGCCAGTT            diff   27.596102
# timecourse_AAACAGCCAGTAAAGC          neuron   37.653171
# timecourse_AAACAGCCATAAGTCT           hiPSC    1.120917
# timecourse_AAACAGCCATAGGCGA            diff   33.677399
# timecourse_AAACAGCCATCACAGC           hiPSC    2.482587
# ...                                     ...         ...
# timecourse_TTTGTTGGTGAGGTAG          neuron   41.142820
# timecourse_TTTGTTGGTGCGCGTA          neuron   57.379511
# timecourse_TTTGTTGGTGTTGTGA            diff   31.413775
# timecourse_TTTGTTGGTTCCGGCT            diff   35.442656
# timecourse_TTTGTTGGTTTACTTG            diff   30.483438
#
#                              pseudotime_clusters_n7  pseudotime_clusters_n14  \
# timecourse_AAACAGCCAGCCAGTT                       3                        6
# timecourse_AAACAGCCAGTAAAGC                       4                        8
# timecourse_AAACAGCCATAAGTCT                       1                        1
# timecourse_AAACAGCCATAGGCGA                       4                        7
# timecourse_AAACAGCCATCACAGC                       1                        1
# ...                                             ...                      ...
# timecourse_TTTGTTGGTGAGGTAG                       5                        9
# timecourse_TTTGTTGGTGCGCGTA                       6                       12
# timecourse_TTTGTTGGTGTTGTGA                       4                        7
# timecourse_TTTGTTGGTTCCGGCT                       4                        8
# timecourse_TTTGTTGGTTTACTTG                       4                        7
#
#                             wsnn_res.0.8              celltype_wnn    sampleID
# timecourse_AAACAGCCAGCCAGTT            3    diff - immature.neuron  timecourse
# timecourse_AAACAGCCAGTAAAGC            6       neuron - excitatory  timecourse
# timecourse_AAACAGCCATAAGTCT            5         diff - hiPSC-like  timecourse
# timecourse_AAACAGCCATAGGCGA            3    diff - immature.neuron  timecourse
# timecourse_AAACAGCCATCACAGC           10        hiPSC - start.diff  timecourse
# ...                                  ...                       ...         ...
# timecourse_TTTGTTGGTGAGGTAG            6       neuron - excitatory  timecourse
# timecourse_TTTGTTGGTGCGCGTA            7  mature.neuron - adhesion  timecourse
# timecourse_TTTGTTGGTGTTGTGA            1                      diff  timecourse
# timecourse_TTTGTTGGTTCCGGCT            1                      diff  timecourse
# timecourse_TTTGTTGGTTTACTTG            1                      diff  timecourse
#
# [7571 rows x 45 columns]

# %% [markdown]
# ### Add a column in adata.obs with the quivalent ATAC-seq barcode

# %%
# Get file with ATAC and RNA barcodes matchings
barcodes_df = pd.read_csv(os.path.join(work_dir, "inputdata/cellBarcodes.rna.atac.timecourse.txt"), sep = " ")
barcodes_dict = dict()

# Create a dictionary where keys are rna barcodes and values atac barcodes
for i in range(len(barcodes_df.index.values)):
    barcodes_dict[barcodes_df.iloc[i,0]] = barcodes_df.iloc[i,1]

# %%
adata.obs['barcode'] = [""]*len(adata.obs.index.values)
for i in range(len(adata.obs.index.values)):
    rna_barcodes = adata.obs.index.values
    adata.obs['barcode'][i] = barcodes_dict[rna_barcodes[i][11:]]
# Out:
# /tmp/ipykernel_3094909/2318468678.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adata.obs['barcode'][i] = barcodes_dict[rna_barcodes[i][11:]]

# %%
adata.obs
# Out:
#                              orig.ident  nCount_RNA  nFeature_RNA  percent.mt  \
# timecourse_AAACAGCCAGCCAGTT  timecourse      5020.0          2676    6.155378
# timecourse_AAACAGCCAGTAAAGC  timecourse      3832.0          2004    0.287056
# timecourse_AAACAGCCATAAGTCT  timecourse      7329.0          3535    1.159776
# timecourse_AAACAGCCATAGGCGA  timecourse      4511.0          2253    7.337619
# timecourse_AAACAGCCATCACAGC  timecourse     12095.0          4857    6.572964
# ...                                 ...         ...           ...         ...
# timecourse_TTTGTTGGTGAGGTAG  timecourse      5826.0          2665    5.029180
# timecourse_TTTGTTGGTGCGCGTA  timecourse     13128.0          5157    6.093845
# timecourse_TTTGTTGGTGTTGTGA  timecourse      3832.0          2250    7.489562
# timecourse_TTTGTTGGTTCCGGCT  timecourse      6420.0          3037    7.009346
# timecourse_TTTGTTGGTTTACTTG  timecourse     11224.0          4259    7.189950
#
#                              percent.ribo  nCount_SCT  nFeature_SCT  \
# timecourse_AAACAGCCAGCCAGTT      3.705179      6577.0          2676
# timecourse_AAACAGCCAGTAAAGC      0.730689      6634.0          2045
# timecourse_AAACAGCCATAAGTCT      1.132487      7330.0          3535
# timecourse_AAACAGCCATAGGCGA      1.906451      6652.0          2254
# timecourse_AAACAGCCATCACAGC      1.537826      8336.0          4694
# ...                                   ...         ...           ...
# timecourse_TTTGTTGGTGAGGTAG      0.944044      6678.0          2665
# timecourse_TTTGTTGGTGCGCGTA      1.706277      8351.0          4729
# timecourse_TTTGTTGGTGTTGTGA      3.183716      6674.0          2285
# timecourse_TTTGTTGGTTCCGGCT      1.043614      6780.0          3035
# timecourse_TTTGTTGGTTTACTTG      1.505702      8166.0          4220
#
#                             SCT_snn_res.0.5 seurat_clusters  \
# timecourse_AAACAGCCAGCCAGTT               2               3
# timecourse_AAACAGCCAGTAAAGC               5               5
# timecourse_AAACAGCCATAAGTCT               7               6
# timecourse_AAACAGCCATAGGCGA               3               3
# timecourse_AAACAGCCATCACAGC              12               8
# ...                                     ...             ...
# timecourse_TTTGTTGGTGAGGTAG               5               5
# timecourse_TTTGTTGGTGCGCGTA               9               7
# timecourse_TTTGTTGGTGTTGTGA               2               2
# timecourse_TTTGTTGGTTCCGGCT               2               2
# timecourse_TTTGTTGGTTTACTTG               2               2
#
#                              pANN_0.25_0.005_794  ... SCT_nn_res.0.5  \
# timecourse_AAACAGCCAGCCAGTT             0.084507  ...              3
# timecourse_AAACAGCCAGTAAAGC             0.183099  ...              9
# timecourse_AAACAGCCATAAGTCT             0.154930  ...              7
# timecourse_AAACAGCCATAGGCGA             0.140845  ...              3
# timecourse_AAACAGCCATCACAGC             0.028169  ...              7
# ...                                          ...  ...            ...
# timecourse_TTTGTTGGTGAGGTAG             0.070423  ...              9
# timecourse_TTTGTTGGTGCGCGTA             0.577465  ...             10
# timecourse_TTTGTTGGTGTTGTGA             0.197183  ...              2
# timecourse_TTTGTTGGTTCCGGCT             0.098592  ...              2
# timecourse_TTTGTTGGTTTACTTG             0.154930  ...              2
#
#                                              celltype basic_celltype  \
# timecourse_AAACAGCCAGCCAGTT    diff - immature.neuron           diff
# timecourse_AAACAGCCAGTAAAGC       neuron - excitatory         neuron
# timecourse_AAACAGCCATAAGTCT        hiPSC - start.diff          hiPSC
# timecourse_AAACAGCCATAGGCGA    diff - immature.neuron           diff
# timecourse_AAACAGCCATCACAGC        hiPSC - start.diff          hiPSC
# ...                                               ...            ...
# timecourse_TTTGTTGGTGAGGTAG       neuron - excitatory         neuron
# timecourse_TTTGTTGGTGCGCGTA  mature.neuron - adhesion         neuron
# timecourse_TTTGTTGGTGTTGTGA                      diff           diff
# timecourse_TTTGTTGGTTCCGGCT                      diff           diff
# timecourse_TTTGTTGGTTTACTTG                      diff           diff
#
#                              pseudotime  pseudotime_clusters_n7  \
# timecourse_AAACAGCCAGCCAGTT   27.596102                       3
# timecourse_AAACAGCCAGTAAAGC   37.653171                       4
# timecourse_AAACAGCCATAAGTCT    1.120917                       1
# timecourse_AAACAGCCATAGGCGA   33.677399                       4
# timecourse_AAACAGCCATCACAGC    2.482587                       1
# ...                                 ...                     ...
# timecourse_TTTGTTGGTGAGGTAG   41.142820                       5
# timecourse_TTTGTTGGTGCGCGTA   57.379511                       6
# timecourse_TTTGTTGGTGTTGTGA   31.413775                       4
# timecourse_TTTGTTGGTTCCGGCT   35.442656                       4
# timecourse_TTTGTTGGTTTACTTG   30.483438                       4
#
#                              pseudotime_clusters_n14  wsnn_res.0.8  \
# timecourse_AAACAGCCAGCCAGTT                        6             3
# timecourse_AAACAGCCAGTAAAGC                        8             6
# timecourse_AAACAGCCATAAGTCT                        1             5
# timecourse_AAACAGCCATAGGCGA                        7             3
# timecourse_AAACAGCCATCACAGC                        1            10
# ...                                              ...           ...
# timecourse_TTTGTTGGTGAGGTAG                        9             6
# timecourse_TTTGTTGGTGCGCGTA                       12             7
# timecourse_TTTGTTGGTGTTGTGA                        7             1
# timecourse_TTTGTTGGTTCCGGCT                        8             1
# timecourse_TTTGTTGGTTTACTTG                        7             1
#
#                                          celltype_wnn    sampleID  \
# timecourse_AAACAGCCAGCCAGTT    diff - immature.neuron  timecourse
# timecourse_AAACAGCCAGTAAAGC       neuron - excitatory  timecourse
# timecourse_AAACAGCCATAAGTCT         diff - hiPSC-like  timecourse
# timecourse_AAACAGCCATAGGCGA    diff - immature.neuron  timecourse
# timecourse_AAACAGCCATCACAGC        hiPSC - start.diff  timecourse
# ...                                               ...         ...
# timecourse_TTTGTTGGTGAGGTAG       neuron - excitatory  timecourse
# timecourse_TTTGTTGGTGCGCGTA  mature.neuron - adhesion  timecourse
# timecourse_TTTGTTGGTGTTGTGA                      diff  timecourse
# timecourse_TTTGTTGGTTCCGGCT                      diff  timecourse
# timecourse_TTTGTTGGTTTACTTG                      diff  timecourse
#
#                                       barcode
# timecourse_AAACAGCCAGCCAGTT  AAACCGTACCCGCTGT
# timecourse_AAACAGCCAGTAAAGC  CTAGTAAACCCGCTGT
# timecourse_AAACAGCCATAAGTCT  TGGCATGACCCGCTGT
# timecourse_AAACAGCCATAGGCGA  TTTGTGCACCCGCTGT
# timecourse_AAACAGCCATCACAGC  TCCAGGAACCCGCTGT
# ...                                       ...
# timecourse_TTTGTTGGTGAGGTAG  CAGGTCCTGAAGTACG
# timecourse_TTTGTTGGTGCGCGTA  CGGCACTTGAAGTACG
# timecourse_TTTGTTGGTGTTGTGA  GGCTTCATGAAGTACG
# timecourse_TTTGTTGGTTCCGGCT  GCAGGCATGAAGTACG
# timecourse_TTTGTTGGTTTACTTG  GGATTGATGAAGTACG
#
# [7571 rows x 46 columns]

# %% [markdown]
# ### Subset the adata object for code debugging

# %%
adata_full = adata
adata = sc.pp.subsample(adata_full, fraction = 0.1, copy = True)

# %%
adata.obs
# Out:
#                              orig.ident  nCount_RNA  nFeature_RNA  percent.mt  \
# timecourse_GCGGTTGGTAACGTGC  timecourse      7372.0          3241   11.516549
# timecourse_AAGCCTCCAATCCTGA  timecourse      5596.0          2285    0.178699
# timecourse_GGCTGTCAGTTGTCCC  timecourse      6767.0          3109    9.915768
# timecourse_AGAGATTAGGGTCTAT  timecourse      3941.0          2071    0.355240
# timecourse_TCGTTATTCGCCTAAG  timecourse      2149.0          1407   11.633318
# ...                                 ...         ...           ...         ...
# timecourse_GAGTAACCATCCTAGA  timecourse      4619.0          2664    2.359818
# timecourse_TCTAACCGTTGGTTCT  timecourse      6192.0          2610    4.731912
# timecourse_CATAATCCATGTCGCG  timecourse      4049.0          2435    3.754013
# timecourse_TTTGCGACAGTTATCG  timecourse     22122.0          5835    0.226019
# timecourse_CACAAGCGTACCAGGT  timecourse      6843.0          3329   10.828584
#
#                              percent.ribo  nCount_SCT  nFeature_SCT  \
# timecourse_GCGGTTGGTAACGTGC      2.902876      7372.0          3241
# timecourse_AAGCCTCCAATCCTGA      0.321658      6674.0          2283
# timecourse_GGCTGTCAGTTGTCCC      3.058963      6935.0          3108
# timecourse_AGAGATTAGGGTCTAT      0.761228      6663.0          2089
# timecourse_TCGTTATTCGCCTAAG      2.326664      6189.0          1968
# ...                                   ...         ...           ...
# timecourse_GAGTAACCATCCTAGA      2.208270      6478.0          2666
# timecourse_TCTAACCGTTGGTTCT      0.645995      6780.0          2609
# timecourse_CATAATCCATGTCGCG      1.778217      6620.0          2447
# timecourse_TTTGCGACAGTTATCG      0.479161      7707.0          3437
# timecourse_CACAAGCGTACCAGGT      3.331872      6964.0          3327
#
#                             SCT_snn_res.0.5 seurat_clusters  \
# timecourse_GCGGTTGGTAACGTGC               0               1
# timecourse_AAGCCTCCAATCCTGA               4               4
# timecourse_GGCTGTCAGTTGTCCC               0               1
# timecourse_AGAGATTAGGGTCTAT               5               5
# timecourse_TCGTTATTCGCCTAAG               2               2
# ...                                     ...             ...
# timecourse_GAGTAACCATCCTAGA               0               1
# timecourse_TCTAACCGTTGGTTCT               6               5
# timecourse_CATAATCCATGTCGCG               0               1
# timecourse_TTTGCGACAGTTATCG              10               7
# timecourse_CACAAGCGTACCAGGT               7               6
#
#                              pANN_0.25_0.005_794  ... SCT_nn_res.0.5  \
# timecourse_GCGGTTGGTAACGTGC             0.098592  ...              0
# timecourse_AAGCCTCCAATCCTGA             0.056338  ...              4
# timecourse_GGCTGTCAGTTGTCCC             0.056338  ...              0
# timecourse_AGAGATTAGGGTCTAT             0.084507  ...              9
# timecourse_TCGTTATTCGCCTAAG             0.183099  ...              2
# ...                                          ...  ...            ...
# timecourse_GAGTAACCATCCTAGA             0.253521  ...              0
# timecourse_TCTAACCGTTGGTTCT             0.070423  ...              8
# timecourse_CATAATCCATGTCGCG             0.084507  ...              0
# timecourse_TTTGCGACAGTTATCG             0.070423  ...             10
# timecourse_CACAAGCGTACCAGGT             0.084507  ...              6
#
#                                              celltype basic_celltype  \
# timecourse_GCGGTTGGTAACGTGC           diff - NPC-like           diff
# timecourse_AAGCCTCCAATCCTGA    neuron - mature.neuron         neuron
# timecourse_GGCTGTCAGTTGTCCC           diff - NPC-like           diff
# timecourse_AGAGATTAGGGTCTAT       neuron - excitatory         neuron
# timecourse_TCGTTATTCGCCTAAG                      diff           diff
# ...                                               ...            ...
# timecourse_GAGTAACCATCCTAGA           diff - NPC-like           diff
# timecourse_TCTAACCGTTGGTTCT      neuron - development         neuron
# timecourse_CATAATCCATGTCGCG           diff - NPC-like           diff
# timecourse_TTTGCGACAGTTATCG  mature.neuron - adhesion         neuron
# timecourse_CACAAGCGTACCAGGT         diff - hiPSC-like           diff
#
#                              pseudotime  pseudotime_clusters_n7  \
# timecourse_GCGGTTGGTAACGTGC   24.902457                       3
# timecourse_AAGCCTCCAATCCTGA   59.514298                       6
# timecourse_GGCTGTCAGTTGTCCC   23.183780                       3
# timecourse_AGAGATTAGGGTCTAT   37.680784                       4
# timecourse_TCGTTATTCGCCTAAG   31.633097                       4
# ...                                 ...                     ...
# timecourse_GAGTAACCATCCTAGA   25.236132                       3
# timecourse_TCTAACCGTTGGTTCT   42.729866                       5
# timecourse_CATAATCCATGTCGCG   25.116435                       3
# timecourse_TTTGCGACAGTTATCG   57.454289                       6
# timecourse_CACAAGCGTACCAGGT    5.817692                       1
#
#                              pseudotime_clusters_n14  wsnn_res.0.8  \
# timecourse_GCGGTTGGTAACGTGC                        5             8
# timecourse_AAGCCTCCAATCCTGA                       12             4
# timecourse_GGCTGTCAGTTGTCCC                        5             8
# timecourse_AGAGATTAGGGTCTAT                        8             6
# timecourse_TCGTTATTCGCCTAAG                        7             1
# ...                                              ...           ...
# timecourse_GAGTAACCATCCTAGA                        6             2
# timecourse_TCTAACCGTTGGTTCT                        9             6
# timecourse_CATAATCCATGTCGCG                        6             2
# timecourse_TTTGCGACAGTTATCG                       12             7
# timecourse_CACAAGCGTACCAGGT                        2             5
#
#                                          celltype_wnn    sampleID  \
# timecourse_GCGGTTGGTAACGTGC           diff - NPC-like  timecourse
# timecourse_AAGCCTCCAATCCTGA    neuron - mature.neuron  timecourse
# timecourse_GGCTGTCAGTTGTCCC           diff - NPC-like  timecourse
# timecourse_AGAGATTAGGGTCTAT       neuron - excitatory  timecourse
# timecourse_TCGTTATTCGCCTAAG                      diff  timecourse
# ...                                               ...         ...
# timecourse_GAGTAACCATCCTAGA           diff - NPC-like  timecourse
# timecourse_TCTAACCGTTGGTTCT       neuron - excitatory  timecourse
# timecourse_CATAATCCATGTCGCG           diff - NPC-like  timecourse
# timecourse_TTTGCGACAGTTATCG  mature.neuron - adhesion  timecourse
# timecourse_CACAAGCGTACCAGGT         diff - hiPSC-like  timecourse
#
#                                       barcode
# timecourse_GCGGTTGGTAACGTGC  GCCTCAATGACAGAAC
# timecourse_AAGCCTCCAATCCTGA  ATTGTCTACTAAAGCT
# timecourse_GGCTGTCAGTTGTCCC  TTTGTACGAGTAACTA
# timecourse_AGAGATTAGGGTCTAT  GATTTGAGAAGTAATC
# timecourse_TCGTTATTCGCCTAAG  CCCTTTACTACAAACA
# ...                                       ...
# timecourse_GAGTAACCATCCTAGA  AAGACAAACTTGCTCA
# timecourse_TCTAACCGTTGGTTCT  AGCCTTGTGCATCCCT
# timecourse_CATAATCCATGTCGCG  CTAACTCACAATACCG
# timecourse_TTTGCGACAGTTATCG  GGAATAAACCTCACAT
# timecourse_CACAAGCGTACCAGGT  CCGATTATGAACGAAC
#
# [757 rows x 46 columns]

# %%
# Save it
adata.__dict__['_raw'].__dict__['_var'] = adata.__dict__['_raw'].__dict__['_var'].rename(columns={'_index': 'features'})
adata.write(os.path.join(tmp_dir,'timecourse.nomicro.subset.adata.h5ad'), compression='gzip')
